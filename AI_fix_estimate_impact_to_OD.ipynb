# %% [markdown]
# # ESTIMATE IMPACT TO OD MATRIX
# ### Chọn ra cặp OD điển hình để khảo sát tỉ lệ chuyển đôi, phân vị thời gian ....

# %%
import yaml
import pandas as pd
import numpy as np
from lxml import etree
import seaborn as sns
import matplotlib.pyplot as plt

import shutil
import os
import csv

# %% [markdown]
# # 0. Set up các file

# %% [markdown]
# #### Simple test

# %%
# TRANSIT_VEHICLE_PATH = "data\\simple_scenario\\transitVehicles.xml"
# EVENT_PATH = "data\\simple_scenario\\output\\output_events.xml"
# PLAN_PATH = "data\\simple_scenario\\plans.xml"
# NETWORK_PATH = "data\\simple_scenario\\network.xml"
# OUTPUT_EVENT_AFTER_PROCESSOR = "data\\simple_scenario\\scoring\\estimate_impact_to_OD\\trip_from_zone_to_zone.csv"

# OUTPUT_RESULT_FOLDER = "data\\simple_scenario\\scoring\\estimate_impact_to_OD\\visaulize"
# OUTPUT_EVENT_AFTER_PROCESSOR_IN_DRAW_MODE = OUTPUT_RESULT_FOLDER + "\\trip_from_zone_to_zone_draw_mode.csv"

# %% [markdown]
# ### After Scenario

# %%
# TRANSIT_VEHICLE_PATH = "data\\after\\output_transitVehicles.xml"
# EVENT_PATH = "data\\after\\output_events.xml"
# PLAN_PATH = "data\\after\\plans_scale0.375true.xml"
# NETWORK_PATH = "data\\after\\network.xml"
# OUTPUT_EVENT_AFTER_PROCESSOR = "data\\after\\scoring\\estimate_impact_to_OD\\trip_from_zone_to_zone.csv"

# OUTPUT_RESULT_FOLDER = "data\\after\\scoring\\estimate_impact_to_OD\\visaulize"
# OUTPUT_EVENT_AFTER_PROCESSOR_IN_DRAW_MODE = OUTPUT_RESULT_FOLDER + "\\trip_from_zone_to_zone_draw_mode.csv"

# SCHEDULE_PATH = "data\\after\\output_transitSchedule.xml"

# NAME_SCENARIO = "AFTER IMPROVEMENT"  # Change this value accordingly

# %% [markdown]
# ### Before Scenario

# %%
TRANSIT_VEHICLE_PATH = "data\\before\\output_transitVehicles.xml"
EVENT_PATH = "data\\before\\output_events.xml"
PLAN_PATH = "data\\before\\plans_scale0.375true.xml"
NETWORK_PATH = "data\\before\\network.xml"
OUTPUT_EVENT_AFTER_PROCESSOR = "data\\before\\scoring\\estimate_impact_to_OD\\trip_from_zone_to_zone.csv"
SCHEDULE_PATH = "data\\before\\output_transitSchedule.xml"

OUTPUT_RESULT_FOLDER = "data\\before\\scoring\\estimate_impact_to_OD\\visaulize"
OUTPUT_EVENT_AFTER_PROCESSOR_IN_DRAW_MODE = OUTPUT_RESULT_FOLDER + "\\trip_from_zone_to_zone_draw_mode.csv"
NAME_SCENARIO = "BEFORE IMPROVEMENT"  # Change this value accordingly

# %% [markdown]
# ### Real Scenario

# %%
# TRANSIT_VEHICLE_PATH = "data\\real\\output_transitVehicles.xml"
# EVENT_PATH = "data\\real\\output_events.xml"
# PLAN_PATH = "data\\real\\plans_scale0.375truelans.xml"
# NETWORK_PATH = "data\\real\\network.xml"
# OUTPUT_EVENT_AFTER_PROCESSOR = "data\\real\\scoring\\estimate_impact_to_OD\\trip_from_zone_to_zone.csv"

# OUTPUT_RESULT_FOLDER = "data\\real\\scoring\\estimate_impact_to_OD\\visaulize"
# OUTPUT_EVENT_AFTER_PROCESSOR_IN_DRAW_MODE = OUTPUT_RESULT_FOLDER + "\\trip_from_zone_to_zone_draw_mode.csv"

# %%
if os.path.exists(OUTPUT_EVENT_AFTER_PROCESSOR):
    os.remove(OUTPUT_EVENT_AFTER_PROCESSOR)

folder_path = os.path.dirname(OUTPUT_EVENT_AFTER_PROCESSOR)
os.makedirs(folder_path, exist_ok=True)

if os.path.exists(OUTPUT_RESULT_FOLDER):
    shutil.rmtree(OUTPUT_RESULT_FOLDER)

os.makedirs(OUTPUT_RESULT_FOLDER, exist_ok=True)

# %% [markdown]
# ## 1. Tạo class zone và point và kiểm tra xem 1 point có nằm trong zone ko

# %%
class Point:
    def __init__(self, x, y):
        self.x = float(x)
        self.y = float(y)

class Zone:
    def __init__(self, zone_id, boundary_points: list[Point]):
        self.zone_id = zone_id
        self.boundary = boundary_points

    def print_boundary(self):
        print(f"Zone ID: {self.zone_id}")
        for point in self.boundary:
            print(f"({point.x}, {point.y})")

    def is_in_zone(self, point: Point) -> bool:
        """
        Kiểm tra điểm có nằm trong vùng không (bao gồm cả biên)
        Sử dụng Ray Casting Algorithm
        """
        if len(self.boundary) < 3:
            return False
        
        n = len(self.boundary)
        inside = False
        
        # Kiểm tra điểm có nằm trên biên không
        for i in range(n):
            p1 = self.boundary[i]
            p2 = self.boundary[(i + 1) % n]
            
            if self._point_on_segment(point, p1, p2):
                return True
        
        # Ray casting algorithm - bắn tia từ điểm về phía phải
        p1 = self.boundary[0]
        for i in range(1, n + 1):
            p2 = self.boundary[i % n]
            
            # Kiểm tra xem tia ngang đi qua cạnh này không
            if point.y > min(p1.y, p2.y):
                if point.y <= max(p1.y, p2.y):
                    if point.x <= max(p1.x, p2.x):
                        if p1.y != p2.y:
                            x_intersection = (point.y - p1.y) * (p2.x - p1.x) / (p2.y - p1.y) + p1.x
                        
                        if p1.x == p2.x or point.x <= x_intersection:
                            inside = not inside
            p1 = p2
        
        return inside
    
    def _point_on_segment(self, point: Point, p1: Point, p2: Point) -> bool:
        """
        Kiểm tra điểm có nằm trên đoạn thẳng p1-p2 không
        """
        # Kiểm tra điểm có nằm trong hình chữ nhật bao quanh đoạn thẳng
        if not (min(p1.x, p2.x) <= point.x <= max(p1.x, p2.x) and
                min(p1.y, p2.y) <= point.y <= max(p1.y, p2.y)):
            return False
        
        # Kiểm tra 3 điểm thẳng hàng bằng cross product
        # Cross product = 0 nghĩa là thẳng hàng
        cross = (point.y - p1.y) * (p2.x - p1.x) - (point.x - p1.x) * (p2.y - p1.y)
        
        # Dùng epsilon để xử lý sai số float
        epsilon = 1e-10
        return abs(cross) < epsilon

# %% [markdown]
# #### Test code kiểm tra 1 điểm trong zone

# %%
zone = Zone("zone1", [
        Point(0, 0),
        Point(10, 0),
        Point(10, 10),
        Point(0, 10)
    ])
    
    # Test các điểm
test_points = [
    (Point(5, 5), "Điểm ở trong"),           # True - trong vùng
    (Point(0, 0), "Điểm ở đỉnh"),            # True - trên biên (đỉnh)
    (Point(5, 0), "Điểm ở cạnh"),            # True - trên biên (cạnh)
    (Point(15, 5), "Điểm ở ngoài"),          # False - ngoài vùng
    (Point(10, 5), "Điểm ở cạnh phải"),      # True - trên biên
]
    
for point, description in test_points:
    result = zone.is_in_zone(point)
    print(f"{description} ({point.x}, {point.y}): {result}")
# Out:
# Điểm ở trong (5.0, 5.0): True
# Điểm ở đỉnh (0.0, 0.0): True
# Điểm ở cạnh (5.0, 0.0): True
# Điểm ở ngoài (15.0, 5.0): False
# Điểm ở cạnh phải (10.0, 5.0): True

# %% [markdown]
# ## 2. Tạo ra simple_zone từ Hàm sinh ra Zone theo ô bàn cờ x hàng y côt dựa trên xml netwwork đưa vào

# %%
# !powershell -Command "Get-Content 'data\\simple_scenario\\network.xml' -TotalCount 20 | ForEach-Object { '{0:5}: {1}' -f $_.ReadCount, $_ }"
# Out:
# 5: <?xml version="1.0" encoding="UTF-8"?>
# 5: <!DOCTYPE network SYSTEM "http://www.matsim.org/files/dtd/network_v1.dtd">
# 5: <network>
# 5:   <nodes>
# 5:     <node id="n_0_0" x="460000.0" y="5740000.0" />
# 5:     <node id="n_1_0" x="463000.0" y="5740000.0" />
# 5:     <node id="n_2_0" x="466000.0" y="5740000.0" />
# 5:     <node id="n_3_0" x="469000.0" y="5740000.0" />
# 5:     <node id="n_4_0" x="472000.0" y="5740000.0" />
# 5:     <node id="n_5_0" x="475000.0" y="5740000.0" />
# 5:     <node id="n_0_1" x="460000.0" y="5743000.0" />
# 5:     <node id="n_1_1" x="463000.0" y="5743000.0" />
# 5:     <node id="n_2_1" x="466000.0" y="5743000.0" />
# 5:     <node id="n_3_1" x="469000.0" y="5743000.0" />
# 5:     <node id="n_4_1" x="472000.0" y="5743000.0" />
# 5:     <node id="n_5_1" x="475000.0" y="5743000.0" />
# 5:     <node id="n_0_2" x="460000.0" y="5746000.0" />
# 5:     <node id="n_1_2" x="463000.0" y="5746000.0" />
# 5:     <node id="n_2_2" x="466000.0" y="5746000.0" />
# 5:     <node id="n_3_2" x="469000.0" y="5746000.0" />

# %%
def generate_checkerboard_shape_zone_from_network(network_path: str, rows: int, cols: int) -> list[Zone]:
    """
    Tạo các vùng hình chữ nhật dạng bàn cờ từ mạng lưới giao thông
    network_path: đường dẫn file mạng lưới (XML)
    rows: số hàng
    cols: số cột
    Trả về danh sách các vùng Zone
    """
    tree = etree.parse(network_path)
    root = tree.getroot()
    
    x_values = []
    y_values = []
    
    for node in root.xpath('//network/nodes/node'):
        x = float(node.get('x'))
        y = float(node.get('y'))
        x_values.append(x)
        y_values.append(y)
    
    min_x, max_x = min(x_values), max(x_values)
    min_y, max_y = min(y_values), max(y_values)

    print(f"Network bounds: X({min_x}, {max_x}), Y({min_y}, {max_y})")
    
    zone_width = (max_x - min_x) / cols
    zone_height = (max_y - min_y) / rows
    
    zones = []
    
    for i in range(rows):
        for j in range(cols):
            zone_id = f"zone_{i}_{j}"
            boundary_points = [
                Point(min_x + j * zone_width, min_y + i * zone_height),
                Point(min_x + (j + 1) * zone_width, min_y + i * zone_height),
                Point(min_x + (j + 1) * zone_width, min_y + (i + 1) * zone_height),
                Point(min_x + j * zone_width, min_y + (i + 1) * zone_height)
            ]
            zones.append(Zone(zone_id, boundary_points))
    
    return zones

# %%
test_zones : list[Zone]= generate_checkerboard_shape_zone_from_network(NETWORK_PATH, 4, 4)
for zone in test_zones:
    zone.print_boundary()
# Out:
# Network bounds: X(439460.06825334975, 483552.56240213366), Y(5711222.598506039, 5766338.24313264)
# Zone ID: zone_0_0
# (439460.06825334975, 5711222.598506039)
# (450483.1917905457, 5711222.598506039)
# (450483.1917905457, 5725001.50966269)
# (439460.06825334975, 5725001.50966269)
# Zone ID: zone_0_1
# (450483.1917905457, 5711222.598506039)
# (461506.3153277417, 5711222.598506039)
# (461506.3153277417, 5725001.50966269)
# (450483.1917905457, 5725001.50966269)
# Zone ID: zone_0_2
# (461506.3153277417, 5711222.598506039)
# (472529.4388649377, 5711222.598506039)
# (472529.4388649377, 5725001.50966269)
# (461506.3153277417, 5725001.50966269)
# Zone ID: zone_0_3
# (472529.4388649377, 5711222.598506039)
# (483552.56240213366, 5711222.598506039)
# (483552.56240213366, 5725001.50966269)
# (472529.4388649377, 5725001.50966269)
# Zone ID: zone_1_0
# (439460.06825334975, 5725001.50966269)
# (450483.1917905457, 5725001.50966269)
# (450483.1917905457, 5738780.420819339)
# (439460.06825334975, 5738780.420819339)
# Zone ID: zone_1_1
# (450483.1917905457, 5725001.50966269)
# (461506.3153277417, 5725001.50966269)
# (461506.3153277417, 5738780.420819339)
# (450483.1917905457, 5738780.420819339)
# Zone ID: zone_1_2
# (461506.3153277417, 5725001.50966269)
# (472529.4388649377, 5725001.50966269)
# (472529.4388649377, 5738780.420819339)
# (461506.3153277417, 5738780.420819339)
# Zone ID: zone_1_3
# (472529.4388649377, 5725001.50966269)
# (483552.56240213366, 5725001.50966269)
# (483552.56240213366, 5738780.420819339)
# (472529.4388649377, 5738780.420819339)
# Zone ID: zone_2_0
# (439460.06825334975, 5738780.420819339)
# (450483.1917905457, 5738780.420819339)
# (450483.1917905457, 5752559.331975989)
# (439460.06825334975, 5752559.331975989)
# Zone ID: zone_2_1
# (450483.1917905457, 5738780.420819339)
# (461506.3153277417, 5738780.420819339)
# (461506.3153277417, 5752559.331975989)
# (450483.1917905457, 5752559.331975989)
# Zone ID: zone_2_2
# (461506.3153277417, 5738780.420819339)
# (472529.4388649377, 5738780.420819339)
# (472529.4388649377, 5752559.331975989)
# (461506.3153277417, 5752559.331975989)
# Zone ID: zone_2_3
# (472529.4388649377, 5738780.420819339)
# (483552.56240213366, 5738780.420819339)
# (483552.56240213366, 5752559.331975989)
# (472529.4388649377, 5752559.331975989)
# Zone ID: zone_3_0
# (439460.06825334975, 5752559.331975989)
# (450483.1917905457, 5752559.331975989)
# (450483.1917905457, 5766338.24313264)
# (439460.06825334975, 5766338.24313264)
# Zone ID: zone_3_1
# (450483.1917905457, 5752559.331975989)
# (461506.3153277417, 5752559.331975989)
# (461506.3153277417, 5766338.24313264)
# (450483.1917905457, 5766338.24313264)
# Zone ID: zone_3_2
# (461506.3153277417, 5752559.331975989)
# (472529.4388649377, 5752559.331975989)
# (472529.4388649377, 5766338.24313264)
# (461506.3153277417, 5766338.24313264)
# Zone ID: zone_3_3
# (472529.4388649377, 5752559.331975989)
# (483552.56240213366, 5752559.331975989)
# (483552.56240213366, 5766338.24313264)
# (472529.4388649377, 5766338.24313264)

# %% [markdown]
# ## 3. Tạo bảng chứa trip từng người đi từ zone nào đến zone nào trong bao lâu, phương tiện gì
# ### BUS/PT TRAVELTIME INCLUDE PERSON IN BUS/PT AND PERSON WALK, WAIT TO PT/BUS

# %% [markdown]
# ### Xử lý file transit vehicle

# %%
# !powershell -Command "Get-Content 'data\\simple_scenario\\transitVehicles.xml' -TotalCount 20 | ForEach-Object { '{0:5}: {1}' -f $_.ReadCount, $_ }"
# Out:
# 5: <?xml version="1.0" encoding="UTF-8"?>
# 5: <vehicleDefinitions xmlns="http://www.matsim.org/files/dtd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.matsim.org/files/dtd http://www.matsim.org/files/dtd/vehicleDefinitions_v1.0.xsd">
# 5:   <vehicleType id="bus_type"> <capacity><seats persons="50"/><standingRoom persons="0"/></capacity> <length meter="10.0"/> </vehicleType>
# 5:   <vehicleType id="tram_type"> <capacity><seats persons="50"/><standingRoom persons="0"/></capacity> <length meter="10.0"/> </vehicleType>
# 5:   <vehicleType id="train_type"> <capacity><seats persons="100"/><standingRoom persons="0"/></capacity> <length meter="10.0"/> </vehicleType>
# 5:  <vehicle id="veh_Bus_Line_1_dir_fwd_0" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_fwd_1" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_fwd_2" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_fwd_3" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_fwd_4" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_bwd_0" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_bwd_1" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_bwd_2" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_bwd_3" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_1_dir_bwd_4" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_2_dir_fwd_0" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_2_dir_fwd_1" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_2_dir_fwd_2" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_2_dir_fwd_3" type="bus_type"/>
# 5:  <vehicle id="veh_Bus_Line_2_dir_fwd_4" type="bus_type"/>

# %% [markdown]
# ### Xử lý ra dict chứa id và type

# %%
tree = etree.parse(TRANSIT_VEHICLE_PATH)
root = tree.getroot()

# %% [markdown]
# #### xlmn trong thẻ vehicleDefinitions  là namespace cho tất cả các tag trong tag này. nghĩa là tên đầy đủ của tag là {http://www.matsim.org/files/dtd}vehicleDefinitions, {http://www.matsim.org/files/dtd}vehicle.

# %% [markdown]
# #### Khi dùng lxml phải dùng namespace: root.xpath("//m:vehicleDefinitions/m:vehicle", namespaces=ns)

# %%
ns = {'m': 'http://www.matsim.org/files/dtd'}
vehtype_dict = {}


for node in root.xpath("//m:vehicleDefinitions/m:vehicle", namespaces=ns):
    id = node.xpath("@id")[0]
    type = node.xpath("@type")[0]
    print([id,type])
    vehtype_dict[id] = type
# Out:
# ['1_0', 'tram_93pax']
# ['1_1', 'tram_93pax']
# ['1_2', 'tram_93pax']
# ['1_3', 'tram_93pax']
# ['1_4', 'tram_93pax']
# ['2_0', 'tram_93pax']
# ['2_1', 'tram_93pax']
# ['2_2', 'tram_93pax']
# ['2_3', 'tram_93pax']
# ['2_4', 'tram_93pax']
# ['3_0', 'tram_93pax']
# ['3_1', 'tram_93pax']
# ['3_2', 'tram_93pax']
# ['3_3', 'tram_93pax']
# ['3_4', 'tram_93pax']
# ['4_0', 'tram_93pax']
# ['4_1', 'tram_93pax']
# ['4_2', 'tram_93pax']
# ['4_3', 'tram_93pax']
# ['4_4', 'tram_93pax']
# ['rb43_0', 'train']
# ['rb43_1', 'train']
# ['rb43_2', 'train']
# ['rb43_3', 'train']
# ['rb43_4', 'train']
# ['re11_0', 'train']
# ['re11_1', 'train']
# ['re11_2', 'train']
# ['re11_3', 'train']
# ['re11_4', 'train']
# ['re2_0', 'train']
# ['re2_1', 'train']
# ['re2_2', 'train']
# ['re2_3', 'train']
# ['re2_4', 'train']
# ['veh_bus_10_in_07:00:00', 'bus_90pax']
# ['veh_bus_10_in_07:15:00', 'bus_90pax']
# ['veh_bus_10_in_07:30:00', 'bus_90pax']
# ['veh_bus_10_in_07:45:00', 'bus_90pax']
# ['veh_bus_10_in_08:00:00', 'bus_90pax']
# ['veh_bus_10_in_08:15:00', 'bus_90pax']
# ['veh_bus_10_in_08:30:00', 'bus_90pax']
# ['veh_bus_10_in_08:45:00', 'bus_90pax']
# ['veh_bus_10_in_09:00:00', 'bus_90pax']
# ['veh_bus_10_in_09:15:00', 'bus_90pax']
# ['veh_bus_10_in_09:30:00', 'bus_90pax']
# ['veh_bus_10_in_09:45:00', 'bus_90pax']
# ['veh_bus_10_in_10:00:00', 'bus_90pax']
# ['veh_bus_10_in_10:15:00', 'bus_90pax']
# ['veh_bus_10_in_10:30:00', 'bus_90pax']
# ['veh_bus_10_in_10:45:00', 'bus_90pax']
# ['veh_bus_10_in_11:00:00', 'bus_90pax']
# ['veh_bus_10_in_11:15:00', 'bus_90pax']
# ['veh_bus_10_in_11:30:00', 'bus_90pax']
# ['veh_bus_10_in_11:45:00', 'bus_90pax']
# ['veh_bus_10_in_12:00:00', 'bus_90pax']
# ['veh_bus_10_in_12:15:00', 'bus_90pax']
# ['veh_bus_10_in_12:30:00', 'bus_90pax']
# ['veh_bus_10_in_12:45:00', 'bus_90pax']
# ['veh_bus_10_in_13:00:00', 'bus_90pax']
# ['veh_bus_10_in_13:15:00', 'bus_90pax']
# ['veh_bus_10_in_13:30:00', 'bus_90pax']
# ['veh_bus_10_in_13:45:00', 'bus_90pax']
# ['veh_bus_10_in_14:00:00', 'bus_90pax']
# ['veh_bus_10_in_14:15:00', 'bus_90pax']
# ['veh_bus_10_in_14:30:00', 'bus_90pax']
# ['veh_bus_10_in_14:45:00', 'bus_90pax']
# ['veh_bus_10_in_15:00:00', 'bus_90pax']
# ['veh_bus_10_in_15:15:00', 'bus_90pax']
# ['veh_bus_10_in_15:30:00', 'bus_90pax']
# ['veh_bus_10_in_15:45:00', 'bus_90pax']
# ['veh_bus_10_in_16:00:00', 'bus_90pax']
# ['veh_bus_10_in_16:15:00', 'bus_90pax']
# ['veh_bus_10_in_16:30:00', 'bus_90pax']
# ['veh_bus_10_in_16:45:00', 'bus_90pax']
# ['veh_bus_10_in_17:00:00', 'bus_90pax']
# ['veh_bus_10_in_17:15:00', 'bus_90pax']
# ['veh_bus_10_in_17:30:00', 'bus_90pax']
# ['veh_bus_10_in_17:45:00', 'bus_90pax']
# ['veh_bus_10_in_18:00:00', 'bus_90pax']
# ['veh_bus_10_in_18:15:00', 'bus_90pax']
# ['veh_bus_10_in_18:30:00', 'bus_90pax']
# ['veh_bus_10_in_18:45:00', 'bus_90pax']
# ['veh_bus_10_in_19:00:00', 'bus_90pax']
# ['veh_bus_10_in_19:15:00', 'bus_90pax']
# ['veh_bus_10_in_19:30:00', 'bus_90pax']
# ['veh_bus_10_in_19:45:00', 'bus_90pax']
# ['veh_bus_10_in_20:00:00', 'bus_90pax']
# ['veh_bus_10_in_20:15:00', 'bus_90pax']
# ['veh_bus_10_in_20:30:00', 'bus_90pax']
# ['veh_bus_10_in_20:45:00', 'bus_90pax']
# ['veh_bus_10_in_21:00:00', 'bus_90pax']
# ['veh_bus_10_in_21:15:00', 'bus_90pax']
# ['veh_bus_10_in_21:30:00', 'bus_90pax']
# ['veh_bus_10_in_21:45:00', 'bus_90pax']
# ['veh_bus_10_in_22:00:00', 'bus_90pax']
# ['veh_bus_10_out_07:00:00', 'bus_90pax']
# ['veh_bus_10_out_07:15:00', 'bus_90pax']
# ['veh_bus_10_out_07:30:00', 'bus_90pax']
# ['veh_bus_10_out_07:45:00', 'bus_90pax']
# ['veh_bus_10_out_08:00:00', 'bus_90pax']
# ['veh_bus_10_out_08:15:00', 'bus_90pax']
# ['veh_bus_10_out_08:30:00', 'bus_90pax']
# ['veh_bus_10_out_08:45:00', 'bus_90pax']
# ['veh_bus_10_out_09:00:00', 'bus_90pax']
# ['veh_bus_10_out_09:15:00', 'bus_90pax']
# ['veh_bus_10_out_09:30:00', 'bus_90pax']
# ['veh_bus_10_out_09:45:00', 'bus_90pax']
# ['veh_bus_10_out_10:00:00', 'bus_90pax']
# ['veh_bus_10_out_10:15:00', 'bus_90pax']
# ['veh_bus_10_out_10:30:00', 'bus_90pax']
# ['veh_bus_10_out_10:45:00', 'bus_90pax']
# ['veh_bus_10_out_11:00:00', 'bus_90pax']
# ['veh_bus_10_out_11:15:00', 'bus_90pax']
# ['veh_bus_10_out_11:30:00', 'bus_90pax']
# ['veh_bus_10_out_11:45:00', 'bus_90pax']
# ['veh_bus_10_out_12:00:00', 'bus_90pax']
# ['veh_bus_10_out_12:15:00', 'bus_90pax']
# ['veh_bus_10_out_12:30:00', 'bus_90pax']
# ['veh_bus_10_out_12:45:00', 'bus_90pax']
# ['veh_bus_10_out_13:00:00', 'bus_90pax']
# ['veh_bus_10_out_13:15:00', 'bus_90pax']
# ['veh_bus_10_out_13:30:00', 'bus_90pax']
# ['veh_bus_10_out_13:45:00', 'bus_90pax']
# ['veh_bus_10_out_14:00:00', 'bus_90pax']
# ['veh_bus_10_out_14:15:00', 'bus_90pax']
# ['veh_bus_10_out_14:30:00', 'bus_90pax']
# ['veh_bus_10_out_14:45:00', 'bus_90pax']
# ['veh_bus_10_out_15:00:00', 'bus_90pax']
# ['veh_bus_10_out_15:15:00', 'bus_90pax']
# ['veh_bus_10_out_15:30:00', 'bus_90pax']
# ['veh_bus_10_out_15:45:00', 'bus_90pax']
# ['veh_bus_10_out_16:00:00', 'bus_90pax']
# ['veh_bus_10_out_16:15:00', 'bus_90pax']
# ['veh_bus_10_out_16:30:00', 'bus_90pax']
# ['veh_bus_10_out_16:45:00', 'bus_90pax']
# ['veh_bus_10_out_17:00:00', 'bus_90pax']
# ['veh_bus_10_out_17:15:00', 'bus_90pax']
# ['veh_bus_10_out_17:30:00', 'bus_90pax']
# ['veh_bus_10_out_17:45:00', 'bus_90pax']
# ['veh_bus_10_out_18:00:00', 'bus_90pax']
# ['veh_bus_10_out_18:15:00', 'bus_90pax']
# ['veh_bus_10_out_18:30:00', 'bus_90pax']
# ['veh_bus_10_out_18:45:00', 'bus_90pax']
# ['veh_bus_10_out_19:00:00', 'bus_90pax']
# ['veh_bus_10_out_19:15:00', 'bus_90pax']
# ['veh_bus_10_out_19:30:00', 'bus_90pax']
# ['veh_bus_10_out_19:45:00', 'bus_90pax']
# ['veh_bus_10_out_20:00:00', 'bus_90pax']
# ['veh_bus_10_out_20:15:00', 'bus_90pax']
# ['veh_bus_10_out_20:30:00', 'bus_90pax']
# ['veh_bus_10_out_20:45:00', 'bus_90pax']
# ['veh_bus_10_out_21:00:00', 'bus_90pax']
# ['veh_bus_10_out_21:15:00', 'bus_90pax']
# ['veh_bus_10_out_21:30:00', 'bus_90pax']
# ['veh_bus_10_out_21:45:00', 'bus_90pax']
# ['veh_bus_10_out_22:00:00', 'bus_90pax']
# ['veh_bus_12_in_07:00:00', 'bus_90pax']
# ['veh_bus_12_in_07:15:00', 'bus_90pax']
# ['veh_bus_12_in_07:30:00', 'bus_90pax']
# ['veh_bus_12_in_07:45:00', 'bus_90pax']
# ['veh_bus_12_in_08:00:00', 'bus_90pax']
# ['veh_bus_12_in_08:15:00', 'bus_90pax']
# ['veh_bus_12_in_08:30:00', 'bus_90pax']
# ['veh_bus_12_in_08:45:00', 'bus_90pax']
# ['veh_bus_12_in_09:00:00', 'bus_90pax']
# ['veh_bus_12_in_09:15:00', 'bus_90pax']
# ['veh_bus_12_in_09:30:00', 'bus_90pax']
# ['veh_bus_12_in_09:45:00', 'bus_90pax']
# ['veh_bus_12_in_10:00:00', 'bus_90pax']
# ['veh_bus_12_in_10:15:00', 'bus_90pax']
# ['veh_bus_12_in_10:30:00', 'bus_90pax']
# ['veh_bus_12_in_10:45:00', 'bus_90pax']
# ['veh_bus_12_in_11:00:00', 'bus_90pax']
# ['veh_bus_12_in_11:15:00', 'bus_90pax']
# ['veh_bus_12_in_11:30:00', 'bus_90pax']
# ['veh_bus_12_in_11:45:00', 'bus_90pax']
# ['veh_bus_12_in_12:00:00', 'bus_90pax']
# ['veh_bus_12_in_12:15:00', 'bus_90pax']
# ['veh_bus_12_in_12:30:00', 'bus_90pax']
# ['veh_bus_12_in_12:45:00', 'bus_90pax']
# ['veh_bus_12_in_13:00:00', 'bus_90pax']
# ['veh_bus_12_in_13:15:00', 'bus_90pax']
# ['veh_bus_12_in_13:30:00', 'bus_90pax']
# ['veh_bus_12_in_13:45:00', 'bus_90pax']
# ['veh_bus_12_in_14:00:00', 'bus_90pax']
# ['veh_bus_12_in_14:15:00', 'bus_90pax']
# ['veh_bus_12_in_14:30:00', 'bus_90pax']
# ['veh_bus_12_in_14:45:00', 'bus_90pax']
# ['veh_bus_12_in_15:00:00', 'bus_90pax']
# ['veh_bus_12_in_15:15:00', 'bus_90pax']
# ['veh_bus_12_in_15:30:00', 'bus_90pax']
# ['veh_bus_12_in_15:45:00', 'bus_90pax']
# ['veh_bus_12_in_16:00:00', 'bus_90pax']
# ['veh_bus_12_in_16:15:00', 'bus_90pax']
# ['veh_bus_12_in_16:30:00', 'bus_90pax']
# ['veh_bus_12_in_16:45:00', 'bus_90pax']
# ['veh_bus_12_in_17:00:00', 'bus_90pax']
# ['veh_bus_12_in_17:15:00', 'bus_90pax']
# ['veh_bus_12_in_17:30:00', 'bus_90pax']
# ['veh_bus_12_in_17:45:00', 'bus_90pax']
# ['veh_bus_12_in_18:00:00', 'bus_90pax']
# ['veh_bus_12_in_18:15:00', 'bus_90pax']
# ['veh_bus_12_in_18:30:00', 'bus_90pax']
# ['veh_bus_12_in_18:45:00', 'bus_90pax']
# ['veh_bus_12_in_19:00:00', 'bus_90pax']
# ['veh_bus_12_in_19:15:00', 'bus_90pax']
# ['veh_bus_12_in_19:30:00', 'bus_90pax']
# ['veh_bus_12_in_19:45:00', 'bus_90pax']
# ['veh_bus_12_in_20:00:00', 'bus_90pax']
# ['veh_bus_12_in_20:15:00', 'bus_90pax']
# ['veh_bus_12_in_20:30:00', 'bus_90pax']
# ['veh_bus_12_in_20:45:00', 'bus_90pax']
# ['veh_bus_12_in_21:00:00', 'bus_90pax']
# ['veh_bus_12_in_21:15:00', 'bus_90pax']
# ['veh_bus_12_in_21:30:00', 'bus_90pax']
# ['veh_bus_12_in_21:45:00', 'bus_90pax']
# ['veh_bus_12_in_22:00:00', 'bus_90pax']
# ['veh_bus_12_out_07:00:00', 'bus_90pax']
# ['veh_bus_12_out_07:15:00', 'bus_90pax']
# ['veh_bus_12_out_07:30:00', 'bus_90pax']
# ['veh_bus_12_out_07:45:00', 'bus_90pax']
# ['veh_bus_12_out_08:00:00', 'bus_90pax']
# ['veh_bus_12_out_08:15:00', 'bus_90pax']
# ['veh_bus_12_out_08:30:00', 'bus_90pax']
# ['veh_bus_12_out_08:45:00', 'bus_90pax']
# ['veh_bus_12_out_09:00:00', 'bus_90pax']
# ['veh_bus_12_out_09:15:00', 'bus_90pax']
# ['veh_bus_12_out_09:30:00', 'bus_90pax']
# ['veh_bus_12_out_09:45:00', 'bus_90pax']
# ['veh_bus_12_out_10:00:00', 'bus_90pax']
# ['veh_bus_12_out_10:15:00', 'bus_90pax']
# ['veh_bus_12_out_10:30:00', 'bus_90pax']
# ['veh_bus_12_out_10:45:00', 'bus_90pax']
# ['veh_bus_12_out_11:00:00', 'bus_90pax']
# ['veh_bus_12_out_11:15:00', 'bus_90pax']
# ['veh_bus_12_out_11:30:00', 'bus_90pax']
# ['veh_bus_12_out_11:45:00', 'bus_90pax']
# ['veh_bus_12_out_12:00:00', 'bus_90pax']
# ['veh_bus_12_out_12:15:00', 'bus_90pax']
# ['veh_bus_12_out_12:30:00', 'bus_90pax']
# ['veh_bus_12_out_12:45:00', 'bus_90pax']
# ['veh_bus_12_out_13:00:00', 'bus_90pax']
# ['veh_bus_12_out_13:15:00', 'bus_90pax']
# ['veh_bus_12_out_13:30:00', 'bus_90pax']
# ['veh_bus_12_out_13:45:00', 'bus_90pax']
# ['veh_bus_12_out_14:00:00', 'bus_90pax']
# ['veh_bus_12_out_14:15:00', 'bus_90pax']
# ['veh_bus_12_out_14:30:00', 'bus_90pax']
# ['veh_bus_12_out_14:45:00', 'bus_90pax']
# ['veh_bus_12_out_15:00:00', 'bus_90pax']
# ['veh_bus_12_out_15:15:00', 'bus_90pax']
# ['veh_bus_12_out_15:30:00', 'bus_90pax']
# ['veh_bus_12_out_15:45:00', 'bus_90pax']
# ['veh_bus_12_out_16:00:00', 'bus_90pax']
# ['veh_bus_12_out_16:15:00', 'bus_90pax']
# ['veh_bus_12_out_16:30:00', 'bus_90pax']
# ['veh_bus_12_out_16:45:00', 'bus_90pax']
# ['veh_bus_12_out_17:00:00', 'bus_90pax']
# ['veh_bus_12_out_17:15:00', 'bus_90pax']
# ['veh_bus_12_out_17:30:00', 'bus_90pax']
# ['veh_bus_12_out_17:45:00', 'bus_90pax']
# ['veh_bus_12_out_18:00:00', 'bus_90pax']
# ['veh_bus_12_out_18:15:00', 'bus_90pax']
# ['veh_bus_12_out_18:30:00', 'bus_90pax']
# ['veh_bus_12_out_18:45:00', 'bus_90pax']
# ['veh_bus_12_out_19:00:00', 'bus_90pax']
# ['veh_bus_12_out_19:15:00', 'bus_90pax']
# ['veh_bus_12_out_19:30:00', 'bus_90pax']
# ['veh_bus_12_out_19:45:00', 'bus_90pax']
# ['veh_bus_12_out_20:00:00', 'bus_90pax']
# ['veh_bus_12_out_20:15:00', 'bus_90pax']
# ['veh_bus_12_out_20:30:00', 'bus_90pax']
# ['veh_bus_12_out_20:45:00', 'bus_90pax']
# ['veh_bus_12_out_21:00:00', 'bus_90pax']
# ['veh_bus_12_out_21:15:00', 'bus_90pax']
# ['veh_bus_12_out_21:30:00', 'bus_90pax']
# ['veh_bus_12_out_21:45:00', 'bus_90pax']
# ['veh_bus_12_out_22:00:00', 'bus_90pax']
# ['veh_bus_13_in_07:00:00', 'bus_90pax']
# ['veh_bus_13_in_07:15:00', 'bus_90pax']
# ['veh_bus_13_in_07:30:00', 'bus_90pax']
# ['veh_bus_13_in_07:45:00', 'bus_90pax']
# ['veh_bus_13_in_08:00:00', 'bus_90pax']
# ['veh_bus_13_in_08:15:00', 'bus_90pax']
# ['veh_bus_13_in_08:30:00', 'bus_90pax']
# ['veh_bus_13_in_08:45:00', 'bus_90pax']
# ['veh_bus_13_in_09:00:00', 'bus_90pax']
# ['veh_bus_13_in_09:15:00', 'bus_90pax']
# ['veh_bus_13_in_09:30:00', 'bus_90pax']
# ['veh_bus_13_in_09:45:00', 'bus_90pax']
# ['veh_bus_13_in_10:00:00', 'bus_90pax']
# ['veh_bus_13_in_10:15:00', 'bus_90pax']
# ['veh_bus_13_in_10:30:00', 'bus_90pax']
# ['veh_bus_13_in_10:45:00', 'bus_90pax']
# ['veh_bus_13_in_11:00:00', 'bus_90pax']
# ['veh_bus_13_in_11:15:00', 'bus_90pax']
# ['veh_bus_13_in_11:30:00', 'bus_90pax']
# ['veh_bus_13_in_11:45:00', 'bus_90pax']
# ['veh_bus_13_in_12:00:00', 'bus_90pax']
# ['veh_bus_13_in_12:15:00', 'bus_90pax']
# ['veh_bus_13_in_12:30:00', 'bus_90pax']
# ['veh_bus_13_in_12:45:00', 'bus_90pax']
# ['veh_bus_13_in_13:00:00', 'bus_90pax']
# ['veh_bus_13_in_13:15:00', 'bus_90pax']
# ['veh_bus_13_in_13:30:00', 'bus_90pax']
# ['veh_bus_13_in_13:45:00', 'bus_90pax']
# ['veh_bus_13_in_14:00:00', 'bus_90pax']
# ['veh_bus_13_in_14:15:00', 'bus_90pax']
# ['veh_bus_13_in_14:30:00', 'bus_90pax']
# ['veh_bus_13_in_14:45:00', 'bus_90pax']
# ['veh_bus_13_in_15:00:00', 'bus_90pax']
# ['veh_bus_13_in_15:15:00', 'bus_90pax']
# ['veh_bus_13_in_15:30:00', 'bus_90pax']
# ['veh_bus_13_in_15:45:00', 'bus_90pax']
# ['veh_bus_13_in_16:00:00', 'bus_90pax']
# ['veh_bus_13_in_16:15:00', 'bus_90pax']
# ['veh_bus_13_in_16:30:00', 'bus_90pax']
# ['veh_bus_13_in_16:45:00', 'bus_90pax']
# ['veh_bus_13_in_17:00:00', 'bus_90pax']
# ['veh_bus_13_in_17:15:00', 'bus_90pax']
# ['veh_bus_13_in_17:30:00', 'bus_90pax']
# ['veh_bus_13_in_17:45:00', 'bus_90pax']
# ['veh_bus_13_in_18:00:00', 'bus_90pax']
# ['veh_bus_13_in_18:15:00', 'bus_90pax']
# ['veh_bus_13_in_18:30:00', 'bus_90pax']
# ['veh_bus_13_in_18:45:00', 'bus_90pax']
# ['veh_bus_13_in_19:00:00', 'bus_90pax']
# ['veh_bus_13_in_19:15:00', 'bus_90pax']
# ['veh_bus_13_in_19:30:00', 'bus_90pax']
# ['veh_bus_13_in_19:45:00', 'bus_90pax']
# ['veh_bus_13_in_20:00:00', 'bus_90pax']
# ['veh_bus_13_in_20:15:00', 'bus_90pax']
# ['veh_bus_13_in_20:30:00', 'bus_90pax']
# ['veh_bus_13_in_20:45:00', 'bus_90pax']
# ['veh_bus_13_in_21:00:00', 'bus_90pax']
# ['veh_bus_13_in_21:15:00', 'bus_90pax']
# ['veh_bus_13_in_21:30:00', 'bus_90pax']
# ['veh_bus_13_in_21:45:00', 'bus_90pax']
# ['veh_bus_13_in_22:00:00', 'bus_90pax']
# ['veh_bus_13_out_07:00:00', 'bus_90pax']
# ['veh_bus_13_out_07:15:00', 'bus_90pax']
# ['veh_bus_13_out_07:30:00', 'bus_90pax']
# ['veh_bus_13_out_07:45:00', 'bus_90pax']
# ['veh_bus_13_out_08:00:00', 'bus_90pax']
# ['veh_bus_13_out_08:15:00', 'bus_90pax']
# ['veh_bus_13_out_08:30:00', 'bus_90pax']
# ['veh_bus_13_out_08:45:00', 'bus_90pax']
# ['veh_bus_13_out_09:00:00', 'bus_90pax']
# ['veh_bus_13_out_09:15:00', 'bus_90pax']
# ['veh_bus_13_out_09:30:00', 'bus_90pax']
# ['veh_bus_13_out_09:45:00', 'bus_90pax']
# ['veh_bus_13_out_10:00:00', 'bus_90pax']
# ['veh_bus_13_out_10:15:00', 'bus_90pax']
# ['veh_bus_13_out_10:30:00', 'bus_90pax']
# ['veh_bus_13_out_10:45:00', 'bus_90pax']
# ['veh_bus_13_out_11:00:00', 'bus_90pax']
# ['veh_bus_13_out_11:15:00', 'bus_90pax']
# ['veh_bus_13_out_11:30:00', 'bus_90pax']
# ['veh_bus_13_out_11:45:00', 'bus_90pax']
# ['veh_bus_13_out_12:00:00', 'bus_90pax']
# ['veh_bus_13_out_12:15:00', 'bus_90pax']
# ['veh_bus_13_out_12:30:00', 'bus_90pax']
# ['veh_bus_13_out_12:45:00', 'bus_90pax']
# ['veh_bus_13_out_13:00:00', 'bus_90pax']
# ['veh_bus_13_out_13:15:00', 'bus_90pax']
# ['veh_bus_13_out_13:30:00', 'bus_90pax']
# ['veh_bus_13_out_13:45:00', 'bus_90pax']
# ['veh_bus_13_out_14:00:00', 'bus_90pax']
# ['veh_bus_13_out_14:15:00', 'bus_90pax']
# ['veh_bus_13_out_14:30:00', 'bus_90pax']
# ['veh_bus_13_out_14:45:00', 'bus_90pax']
# ['veh_bus_13_out_15:00:00', 'bus_90pax']
# ['veh_bus_13_out_15:15:00', 'bus_90pax']
# ['veh_bus_13_out_15:30:00', 'bus_90pax']
# ['veh_bus_13_out_15:45:00', 'bus_90pax']
# ['veh_bus_13_out_16:00:00', 'bus_90pax']
# ['veh_bus_13_out_16:15:00', 'bus_90pax']
# ['veh_bus_13_out_16:30:00', 'bus_90pax']
# ['veh_bus_13_out_16:45:00', 'bus_90pax']
# ['veh_bus_13_out_17:00:00', 'bus_90pax']
# ['veh_bus_13_out_17:15:00', 'bus_90pax']
# ['veh_bus_13_out_17:30:00', 'bus_90pax']
# ['veh_bus_13_out_17:45:00', 'bus_90pax']
# ['veh_bus_13_out_18:00:00', 'bus_90pax']
# ['veh_bus_13_out_18:15:00', 'bus_90pax']
# ['veh_bus_13_out_18:30:00', 'bus_90pax']
# ['veh_bus_13_out_18:45:00', 'bus_90pax']
# ['veh_bus_13_out_19:00:00', 'bus_90pax']
# ['veh_bus_13_out_19:15:00', 'bus_90pax']
# ['veh_bus_13_out_19:30:00', 'bus_90pax']
# ['veh_bus_13_out_19:45:00', 'bus_90pax']
# ['veh_bus_13_out_20:00:00', 'bus_90pax']
# ['veh_bus_13_out_20:15:00', 'bus_90pax']
# ['veh_bus_13_out_20:30:00', 'bus_90pax']
# ['veh_bus_13_out_20:45:00', 'bus_90pax']
# ['veh_bus_13_out_21:00:00', 'bus_90pax']
# ['veh_bus_13_out_21:15:00', 'bus_90pax']
# ['veh_bus_13_out_21:30:00', 'bus_90pax']
# ['veh_bus_13_out_21:45:00', 'bus_90pax']
# ['veh_bus_13_out_22:00:00', 'bus_90pax']
# ['veh_bus_1417_in_07:00:00', 'bus_90pax']
# ['veh_bus_1417_in_07:15:00', 'bus_90pax']
# ['veh_bus_1417_in_07:30:00', 'bus_90pax']
# ['veh_bus_1417_in_07:45:00', 'bus_90pax']
# ['veh_bus_1417_in_08:00:00', 'bus_90pax']
# ['veh_bus_1417_in_08:15:00', 'bus_90pax']
# ['veh_bus_1417_in_08:30:00', 'bus_90pax']
# ['veh_bus_1417_in_08:45:00', 'bus_90pax']
# ['veh_bus_1417_in_09:00:00', 'bus_90pax']
# ['veh_bus_1417_in_09:15:00', 'bus_90pax']
# ['veh_bus_1417_in_09:30:00', 'bus_90pax']
# ['veh_bus_1417_in_09:45:00', 'bus_90pax']
# ['veh_bus_1417_in_10:00:00', 'bus_90pax']
# ['veh_bus_1417_in_10:15:00', 'bus_90pax']
# ['veh_bus_1417_in_10:30:00', 'bus_90pax']
# ['veh_bus_1417_in_10:45:00', 'bus_90pax']
# ['veh_bus_1417_in_11:00:00', 'bus_90pax']
# ['veh_bus_1417_in_11:15:00', 'bus_90pax']
# ['veh_bus_1417_in_11:30:00', 'bus_90pax']
# ['veh_bus_1417_in_11:45:00', 'bus_90pax']
# ['veh_bus_1417_in_12:00:00', 'bus_90pax']
# ['veh_bus_1417_in_12:15:00', 'bus_90pax']
# ['veh_bus_1417_in_12:30:00', 'bus_90pax']
# ['veh_bus_1417_in_12:45:00', 'bus_90pax']
# ['veh_bus_1417_in_13:00:00', 'bus_90pax']
# ['veh_bus_1417_in_13:15:00', 'bus_90pax']
# ['veh_bus_1417_in_13:30:00', 'bus_90pax']
# ['veh_bus_1417_in_13:45:00', 'bus_90pax']
# ['veh_bus_1417_in_14:00:00', 'bus_90pax']
# ['veh_bus_1417_in_14:15:00', 'bus_90pax']
# ['veh_bus_1417_in_14:30:00', 'bus_90pax']
# ['veh_bus_1417_in_14:45:00', 'bus_90pax']
# ['veh_bus_1417_in_15:00:00', 'bus_90pax']
# ['veh_bus_1417_in_15:15:00', 'bus_90pax']
# ['veh_bus_1417_in_15:30:00', 'bus_90pax']
# ['veh_bus_1417_in_15:45:00', 'bus_90pax']
# ['veh_bus_1417_in_16:00:00', 'bus_90pax']
# ['veh_bus_1417_in_16:15:00', 'bus_90pax']
# ['veh_bus_1417_in_16:30:00', 'bus_90pax']
# ['veh_bus_1417_in_16:45:00', 'bus_90pax']
# ['veh_bus_1417_in_17:00:00', 'bus_90pax']
# ['veh_bus_1417_in_17:15:00', 'bus_90pax']
# ['veh_bus_1417_in_17:30:00', 'bus_90pax']
# ['veh_bus_1417_in_17:45:00', 'bus_90pax']
# ['veh_bus_1417_in_18:00:00', 'bus_90pax']
# ['veh_bus_1417_in_18:15:00', 'bus_90pax']
# ['veh_bus_1417_in_18:30:00', 'bus_90pax']
# ['veh_bus_1417_in_18:45:00', 'bus_90pax']
# ['veh_bus_1417_in_19:00:00', 'bus_90pax']
# ['veh_bus_1417_in_19:15:00', 'bus_90pax']
# ['veh_bus_1417_in_19:30:00', 'bus_90pax']
# ['veh_bus_1417_in_19:45:00', 'bus_90pax']
# ['veh_bus_1417_in_20:00:00', 'bus_90pax']
# ['veh_bus_1417_in_20:15:00', 'bus_90pax']
# ['veh_bus_1417_in_20:30:00', 'bus_90pax']
# ['veh_bus_1417_in_20:45:00', 'bus_90pax']
# ['veh_bus_1417_in_21:00:00', 'bus_90pax']
# ['veh_bus_1417_in_21:15:00', 'bus_90pax']
# ['veh_bus_1417_in_21:30:00', 'bus_90pax']
# ['veh_bus_1417_in_21:45:00', 'bus_90pax']
# ['veh_bus_1417_in_22:00:00', 'bus_90pax']
# ['veh_bus_1417_out_07:00:00', 'bus_90pax']
# ['veh_bus_1417_out_07:15:00', 'bus_90pax']
# ['veh_bus_1417_out_07:30:00', 'bus_90pax']
# ['veh_bus_1417_out_07:45:00', 'bus_90pax']
# ['veh_bus_1417_out_08:00:00', 'bus_90pax']
# ['veh_bus_1417_out_08:15:00', 'bus_90pax']
# ['veh_bus_1417_out_08:30:00', 'bus_90pax']
# ['veh_bus_1417_out_08:45:00', 'bus_90pax']
# ['veh_bus_1417_out_09:00:00', 'bus_90pax']
# ['veh_bus_1417_out_09:15:00', 'bus_90pax']
# ['veh_bus_1417_out_09:30:00', 'bus_90pax']
# ['veh_bus_1417_out_09:45:00', 'bus_90pax']
# ['veh_bus_1417_out_10:00:00', 'bus_90pax']
# ['veh_bus_1417_out_10:15:00', 'bus_90pax']
# ['veh_bus_1417_out_10:30:00', 'bus_90pax']
# ['veh_bus_1417_out_10:45:00', 'bus_90pax']
# ['veh_bus_1417_out_11:00:00', 'bus_90pax']
# ['veh_bus_1417_out_11:15:00', 'bus_90pax']
# ['veh_bus_1417_out_11:30:00', 'bus_90pax']
# ['veh_bus_1417_out_11:45:00', 'bus_90pax']
# ['veh_bus_1417_out_12:00:00', 'bus_90pax']
# ['veh_bus_1417_out_12:15:00', 'bus_90pax']
# ['veh_bus_1417_out_12:30:00', 'bus_90pax']
# ['veh_bus_1417_out_12:45:00', 'bus_90pax']
# ['veh_bus_1417_out_13:00:00', 'bus_90pax']
# ['veh_bus_1417_out_13:15:00', 'bus_90pax']
# ['veh_bus_1417_out_13:30:00', 'bus_90pax']
# ['veh_bus_1417_out_13:45:00', 'bus_90pax']
# ['veh_bus_1417_out_14:00:00', 'bus_90pax']
# ['veh_bus_1417_out_14:15:00', 'bus_90pax']
# ['veh_bus_1417_out_14:30:00', 'bus_90pax']
# ['veh_bus_1417_out_14:45:00', 'bus_90pax']
# ['veh_bus_1417_out_15:00:00', 'bus_90pax']
# ['veh_bus_1417_out_15:15:00', 'bus_90pax']
# ['veh_bus_1417_out_15:30:00', 'bus_90pax']
# ['veh_bus_1417_out_15:45:00', 'bus_90pax']
# ['veh_bus_1417_out_16:00:00', 'bus_90pax']
# ['veh_bus_1417_out_16:15:00', 'bus_90pax']
# ['veh_bus_1417_out_16:30:00', 'bus_90pax']
# ['veh_bus_1417_out_16:45:00', 'bus_90pax']
# ['veh_bus_1417_out_17:00:00', 'bus_90pax']
# ['veh_bus_1417_out_17:15:00', 'bus_90pax']
# ['veh_bus_1417_out_17:30:00', 'bus_90pax']
# ['veh_bus_1417_out_17:45:00', 'bus_90pax']
# ['veh_bus_1417_out_18:00:00', 'bus_90pax']
# ['veh_bus_1417_out_18:15:00', 'bus_90pax']
# ['veh_bus_1417_out_18:30:00', 'bus_90pax']
# ['veh_bus_1417_out_18:45:00', 'bus_90pax']
# ['veh_bus_1417_out_19:00:00', 'bus_90pax']
# ['veh_bus_1417_out_19:15:00', 'bus_90pax']
# ['veh_bus_1417_out_19:30:00', 'bus_90pax']
# ['veh_bus_1417_out_19:45:00', 'bus_90pax']
# ['veh_bus_1417_out_20:00:00', 'bus_90pax']
# ['veh_bus_1417_out_20:15:00', 'bus_90pax']
# ['veh_bus_1417_out_20:30:00', 'bus_90pax']
# ['veh_bus_1417_out_20:45:00', 'bus_90pax']
# ['veh_bus_1417_out_21:00:00', 'bus_90pax']
# ['veh_bus_1417_out_21:15:00', 'bus_90pax']
# ['veh_bus_1417_out_21:30:00', 'bus_90pax']
# ['veh_bus_1417_out_21:45:00', 'bus_90pax']
# ['veh_bus_1417_out_22:00:00', 'bus_90pax']
# ['veh_bus_15_in_07:00:00', 'bus_90pax']
# ['veh_bus_15_in_07:15:00', 'bus_90pax']
# ['veh_bus_15_in_07:30:00', 'bus_90pax']
# ['veh_bus_15_in_07:45:00', 'bus_90pax']
# ['veh_bus_15_in_08:00:00', 'bus_90pax']
# ['veh_bus_15_in_08:15:00', 'bus_90pax']
# ['veh_bus_15_in_08:30:00', 'bus_90pax']
# ['veh_bus_15_in_08:45:00', 'bus_90pax']
# ['veh_bus_15_in_09:00:00', 'bus_90pax']
# ['veh_bus_15_in_09:15:00', 'bus_90pax']
# ['veh_bus_15_in_09:30:00', 'bus_90pax']
# ['veh_bus_15_in_09:45:00', 'bus_90pax']
# ['veh_bus_15_in_10:00:00', 'bus_90pax']
# ['veh_bus_15_in_10:15:00', 'bus_90pax']
# ['veh_bus_15_in_10:30:00', 'bus_90pax']
# ['veh_bus_15_in_10:45:00', 'bus_90pax']
# ['veh_bus_15_in_11:00:00', 'bus_90pax']
# ['veh_bus_15_in_11:15:00', 'bus_90pax']
# ['veh_bus_15_in_11:30:00', 'bus_90pax']
# ['veh_bus_15_in_11:45:00', 'bus_90pax']
# ['veh_bus_15_in_12:00:00', 'bus_90pax']
# ['veh_bus_15_in_12:15:00', 'bus_90pax']
# ['veh_bus_15_in_12:30:00', 'bus_90pax']
# ['veh_bus_15_in_12:45:00', 'bus_90pax']
# ['veh_bus_15_in_13:00:00', 'bus_90pax']
# ['veh_bus_15_in_13:15:00', 'bus_90pax']
# ['veh_bus_15_in_13:30:00', 'bus_90pax']
# ['veh_bus_15_in_13:45:00', 'bus_90pax']
# ['veh_bus_15_in_14:00:00', 'bus_90pax']
# ['veh_bus_15_in_14:15:00', 'bus_90pax']
# ['veh_bus_15_in_14:30:00', 'bus_90pax']
# ['veh_bus_15_in_14:45:00', 'bus_90pax']
# ['veh_bus_15_in_15:00:00', 'bus_90pax']
# ['veh_bus_15_in_15:15:00', 'bus_90pax']
# ['veh_bus_15_in_15:30:00', 'bus_90pax']
# ['veh_bus_15_in_15:45:00', 'bus_90pax']
# ['veh_bus_15_in_16:00:00', 'bus_90pax']
# ['veh_bus_15_in_16:15:00', 'bus_90pax']
# ['veh_bus_15_in_16:30:00', 'bus_90pax']
# ['veh_bus_15_in_16:45:00', 'bus_90pax']
# ['veh_bus_15_in_17:00:00', 'bus_90pax']
# ['veh_bus_15_in_17:15:00', 'bus_90pax']
# ['veh_bus_15_in_17:30:00', 'bus_90pax']
# ['veh_bus_15_in_17:45:00', 'bus_90pax']
# ['veh_bus_15_in_18:00:00', 'bus_90pax']
# ['veh_bus_15_in_18:15:00', 'bus_90pax']
# ['veh_bus_15_in_18:30:00', 'bus_90pax']
# ['veh_bus_15_in_18:45:00', 'bus_90pax']
# ['veh_bus_15_in_19:00:00', 'bus_90pax']
# ['veh_bus_15_in_19:15:00', 'bus_90pax']
# ['veh_bus_15_in_19:30:00', 'bus_90pax']
# ['veh_bus_15_in_19:45:00', 'bus_90pax']
# ['veh_bus_15_in_20:00:00', 'bus_90pax']
# ['veh_bus_15_in_20:15:00', 'bus_90pax']
# ['veh_bus_15_in_20:30:00', 'bus_90pax']
# ['veh_bus_15_in_20:45:00', 'bus_90pax']
# ['veh_bus_15_in_21:00:00', 'bus_90pax']
# ['veh_bus_15_in_21:15:00', 'bus_90pax']
# ['veh_bus_15_in_21:30:00', 'bus_90pax']
# ['veh_bus_15_in_21:45:00', 'bus_90pax']
# ['veh_bus_15_in_22:00:00', 'bus_90pax']
# ['veh_bus_15_out_07:00:00', 'bus_90pax']
# ['veh_bus_15_out_07:15:00', 'bus_90pax']
# ['veh_bus_15_out_07:30:00', 'bus_90pax']
# ['veh_bus_15_out_07:45:00', 'bus_90pax']
# ['veh_bus_15_out_08:00:00', 'bus_90pax']
# ['veh_bus_15_out_08:15:00', 'bus_90pax']
# ['veh_bus_15_out_08:30:00', 'bus_90pax']
# ['veh_bus_15_out_08:45:00', 'bus_90pax']
# ['veh_bus_15_out_09:00:00', 'bus_90pax']
# ['veh_bus_15_out_09:15:00', 'bus_90pax']
# ['veh_bus_15_out_09:30:00', 'bus_90pax']
# ['veh_bus_15_out_09:45:00', 'bus_90pax']
# ['veh_bus_15_out_10:00:00', 'bus_90pax']
# ['veh_bus_15_out_10:15:00', 'bus_90pax']
# ['veh_bus_15_out_10:30:00', 'bus_90pax']
# ['veh_bus_15_out_10:45:00', 'bus_90pax']
# ['veh_bus_15_out_11:00:00', 'bus_90pax']
# ['veh_bus_15_out_11:15:00', 'bus_90pax']
# ['veh_bus_15_out_11:30:00', 'bus_90pax']
# ['veh_bus_15_out_11:45:00', 'bus_90pax']
# ['veh_bus_15_out_12:00:00', 'bus_90pax']
# ['veh_bus_15_out_12:15:00', 'bus_90pax']
# ['veh_bus_15_out_12:30:00', 'bus_90pax']
# ['veh_bus_15_out_12:45:00', 'bus_90pax']
# ['veh_bus_15_out_13:00:00', 'bus_90pax']
# ['veh_bus_15_out_13:15:00', 'bus_90pax']
# ['veh_bus_15_out_13:30:00', 'bus_90pax']
# ['veh_bus_15_out_13:45:00', 'bus_90pax']
# ['veh_bus_15_out_14:00:00', 'bus_90pax']
# ['veh_bus_15_out_14:15:00', 'bus_90pax']
# ['veh_bus_15_out_14:30:00', 'bus_90pax']
# ['veh_bus_15_out_14:45:00', 'bus_90pax']
# ['veh_bus_15_out_15:00:00', 'bus_90pax']
# ['veh_bus_15_out_15:15:00', 'bus_90pax']
# ['veh_bus_15_out_15:30:00', 'bus_90pax']
# ['veh_bus_15_out_15:45:00', 'bus_90pax']
# ['veh_bus_15_out_16:00:00', 'bus_90pax']
# ['veh_bus_15_out_16:15:00', 'bus_90pax']
# ['veh_bus_15_out_16:30:00', 'bus_90pax']
# ['veh_bus_15_out_16:45:00', 'bus_90pax']
# ['veh_bus_15_out_17:00:00', 'bus_90pax']
# ['veh_bus_15_out_17:15:00', 'bus_90pax']
# ['veh_bus_15_out_17:30:00', 'bus_90pax']
# ['veh_bus_15_out_17:45:00', 'bus_90pax']
# ['veh_bus_15_out_18:00:00', 'bus_90pax']
# ['veh_bus_15_out_18:15:00', 'bus_90pax']
# ['veh_bus_15_out_18:30:00', 'bus_90pax']
# ['veh_bus_15_out_18:45:00', 'bus_90pax']
# ['veh_bus_15_out_19:00:00', 'bus_90pax']
# ['veh_bus_15_out_19:15:00', 'bus_90pax']
# ['veh_bus_15_out_19:30:00', 'bus_90pax']
# ['veh_bus_15_out_19:45:00', 'bus_90pax']
# ['veh_bus_15_out_20:00:00', 'bus_90pax']
# ['veh_bus_15_out_20:15:00', 'bus_90pax']
# ['veh_bus_15_out_20:30:00', 'bus_90pax']
# ['veh_bus_15_out_20:45:00', 'bus_90pax']
# ['veh_bus_15_out_21:00:00', 'bus_90pax']
# ['veh_bus_15_out_21:15:00', 'bus_90pax']
# ['veh_bus_15_out_21:30:00', 'bus_90pax']
# ['veh_bus_15_out_21:45:00', 'bus_90pax']
# ['veh_bus_15_out_22:00:00', 'bus_90pax']
# ['veh_bus_16_in_07:00:00', 'bus_90pax']
# ['veh_bus_16_in_07:15:00', 'bus_90pax']
# ['veh_bus_16_in_07:30:00', 'bus_90pax']
# ['veh_bus_16_in_07:45:00', 'bus_90pax']
# ['veh_bus_16_in_08:00:00', 'bus_90pax']
# ['veh_bus_16_in_08:15:00', 'bus_90pax']
# ['veh_bus_16_in_08:30:00', 'bus_90pax']
# ['veh_bus_16_in_08:45:00', 'bus_90pax']
# ['veh_bus_16_in_09:00:00', 'bus_90pax']
# ['veh_bus_16_in_09:15:00', 'bus_90pax']
# ['veh_bus_16_in_09:30:00', 'bus_90pax']
# ['veh_bus_16_in_09:45:00', 'bus_90pax']
# ['veh_bus_16_in_10:00:00', 'bus_90pax']
# ['veh_bus_16_in_10:15:00', 'bus_90pax']
# ['veh_bus_16_in_10:30:00', 'bus_90pax']
# ['veh_bus_16_in_10:45:00', 'bus_90pax']
# ['veh_bus_16_in_11:00:00', 'bus_90pax']
# ['veh_bus_16_in_11:15:00', 'bus_90pax']
# ['veh_bus_16_in_11:30:00', 'bus_90pax']
# ['veh_bus_16_in_11:45:00', 'bus_90pax']
# ['veh_bus_16_in_12:00:00', 'bus_90pax']
# ['veh_bus_16_in_12:15:00', 'bus_90pax']
# ['veh_bus_16_in_12:30:00', 'bus_90pax']
# ['veh_bus_16_in_12:45:00', 'bus_90pax']
# ['veh_bus_16_in_13:00:00', 'bus_90pax']
# ['veh_bus_16_in_13:15:00', 'bus_90pax']
# ['veh_bus_16_in_13:30:00', 'bus_90pax']
# ['veh_bus_16_in_13:45:00', 'bus_90pax']
# ['veh_bus_16_in_14:00:00', 'bus_90pax']
# ['veh_bus_16_in_14:15:00', 'bus_90pax']
# ['veh_bus_16_in_14:30:00', 'bus_90pax']
# ['veh_bus_16_in_14:45:00', 'bus_90pax']
# ['veh_bus_16_in_15:00:00', 'bus_90pax']
# ['veh_bus_16_in_15:15:00', 'bus_90pax']
# ['veh_bus_16_in_15:30:00', 'bus_90pax']
# ['veh_bus_16_in_15:45:00', 'bus_90pax']
# ['veh_bus_16_in_16:00:00', 'bus_90pax']
# ['veh_bus_16_in_16:15:00', 'bus_90pax']
# ['veh_bus_16_in_16:30:00', 'bus_90pax']
# ['veh_bus_16_in_16:45:00', 'bus_90pax']
# ['veh_bus_16_in_17:00:00', 'bus_90pax']
# ['veh_bus_16_in_17:15:00', 'bus_90pax']
# ['veh_bus_16_in_17:30:00', 'bus_90pax']
# ['veh_bus_16_in_17:45:00', 'bus_90pax']
# ['veh_bus_16_in_18:00:00', 'bus_90pax']
# ['veh_bus_16_in_18:15:00', 'bus_90pax']
# ['veh_bus_16_in_18:30:00', 'bus_90pax']
# ['veh_bus_16_in_18:45:00', 'bus_90pax']
# ['veh_bus_16_in_19:00:00', 'bus_90pax']
# ['veh_bus_16_in_19:15:00', 'bus_90pax']
# ['veh_bus_16_in_19:30:00', 'bus_90pax']
# ['veh_bus_16_in_19:45:00', 'bus_90pax']
# ['veh_bus_16_in_20:00:00', 'bus_90pax']
# ['veh_bus_16_in_20:15:00', 'bus_90pax']
# ['veh_bus_16_in_20:30:00', 'bus_90pax']
# ['veh_bus_16_in_20:45:00', 'bus_90pax']
# ['veh_bus_16_in_21:00:00', 'bus_90pax']
# ['veh_bus_16_in_21:15:00', 'bus_90pax']
# ['veh_bus_16_in_21:30:00', 'bus_90pax']
# ['veh_bus_16_in_21:45:00', 'bus_90pax']
# ['veh_bus_16_in_22:00:00', 'bus_90pax']
# ['veh_bus_16_out_07:00:00', 'bus_90pax']
# ['veh_bus_16_out_07:15:00', 'bus_90pax']
# ['veh_bus_16_out_07:30:00', 'bus_90pax']
# ['veh_bus_16_out_07:45:00', 'bus_90pax']
# ['veh_bus_16_out_08:00:00', 'bus_90pax']
# ['veh_bus_16_out_08:15:00', 'bus_90pax']
# ['veh_bus_16_out_08:30:00', 'bus_90pax']
# ['veh_bus_16_out_08:45:00', 'bus_90pax']
# ['veh_bus_16_out_09:00:00', 'bus_90pax']
# ['veh_bus_16_out_09:15:00', 'bus_90pax']
# ['veh_bus_16_out_09:30:00', 'bus_90pax']
# ['veh_bus_16_out_09:45:00', 'bus_90pax']
# ['veh_bus_16_out_10:00:00', 'bus_90pax']
# ['veh_bus_16_out_10:15:00', 'bus_90pax']
# ['veh_bus_16_out_10:30:00', 'bus_90pax']
# ['veh_bus_16_out_10:45:00', 'bus_90pax']
# ['veh_bus_16_out_11:00:00', 'bus_90pax']
# ['veh_bus_16_out_11:15:00', 'bus_90pax']
# ['veh_bus_16_out_11:30:00', 'bus_90pax']
# ['veh_bus_16_out_11:45:00', 'bus_90pax']
# ['veh_bus_16_out_12:00:00', 'bus_90pax']
# ['veh_bus_16_out_12:15:00', 'bus_90pax']
# ['veh_bus_16_out_12:30:00', 'bus_90pax']
# ['veh_bus_16_out_12:45:00', 'bus_90pax']
# ['veh_bus_16_out_13:00:00', 'bus_90pax']
# ['veh_bus_16_out_13:15:00', 'bus_90pax']
# ['veh_bus_16_out_13:30:00', 'bus_90pax']
# ['veh_bus_16_out_13:45:00', 'bus_90pax']
# ['veh_bus_16_out_14:00:00', 'bus_90pax']
# ['veh_bus_16_out_14:15:00', 'bus_90pax']
# ['veh_bus_16_out_14:30:00', 'bus_90pax']
# ['veh_bus_16_out_14:45:00', 'bus_90pax']
# ['veh_bus_16_out_15:00:00', 'bus_90pax']
# ['veh_bus_16_out_15:15:00', 'bus_90pax']
# ['veh_bus_16_out_15:30:00', 'bus_90pax']
# ['veh_bus_16_out_15:45:00', 'bus_90pax']
# ['veh_bus_16_out_16:00:00', 'bus_90pax']
# ['veh_bus_16_out_16:15:00', 'bus_90pax']
# ['veh_bus_16_out_16:30:00', 'bus_90pax']
# ['veh_bus_16_out_16:45:00', 'bus_90pax']
# ['veh_bus_16_out_17:00:00', 'bus_90pax']
# ['veh_bus_16_out_17:15:00', 'bus_90pax']
# ['veh_bus_16_out_17:30:00', 'bus_90pax']
# ['veh_bus_16_out_17:45:00', 'bus_90pax']
# ['veh_bus_16_out_18:00:00', 'bus_90pax']
# ['veh_bus_16_out_18:15:00', 'bus_90pax']
# ['veh_bus_16_out_18:30:00', 'bus_90pax']
# ['veh_bus_16_out_18:45:00', 'bus_90pax']
# ['veh_bus_16_out_19:00:00', 'bus_90pax']
# ['veh_bus_16_out_19:15:00', 'bus_90pax']
# ['veh_bus_16_out_19:30:00', 'bus_90pax']
# ['veh_bus_16_out_19:45:00', 'bus_90pax']
# ['veh_bus_16_out_20:00:00', 'bus_90pax']
# ['veh_bus_16_out_20:15:00', 'bus_90pax']
# ['veh_bus_16_out_20:30:00', 'bus_90pax']
# ['veh_bus_16_out_20:45:00', 'bus_90pax']
# ['veh_bus_16_out_21:00:00', 'bus_90pax']
# ['veh_bus_16_out_21:15:00', 'bus_90pax']
# ['veh_bus_16_out_21:30:00', 'bus_90pax']
# ['veh_bus_16_out_21:45:00', 'bus_90pax']
# ['veh_bus_16_out_22:00:00', 'bus_90pax']
# ['veh_bus_19_in_07:00:00', 'bus_90pax']
# ['veh_bus_19_in_07:15:00', 'bus_90pax']
# ['veh_bus_19_in_07:30:00', 'bus_90pax']
# ['veh_bus_19_in_07:45:00', 'bus_90pax']
# ['veh_bus_19_in_08:00:00', 'bus_90pax']
# ['veh_bus_19_in_08:15:00', 'bus_90pax']
# ['veh_bus_19_in_08:30:00', 'bus_90pax']
# ['veh_bus_19_in_08:45:00', 'bus_90pax']
# ['veh_bus_19_in_09:00:00', 'bus_90pax']
# ['veh_bus_19_in_09:15:00', 'bus_90pax']
# ['veh_bus_19_in_09:30:00', 'bus_90pax']
# ['veh_bus_19_in_09:45:00', 'bus_90pax']
# ['veh_bus_19_in_10:00:00', 'bus_90pax']
# ['veh_bus_19_in_10:15:00', 'bus_90pax']
# ['veh_bus_19_in_10:30:00', 'bus_90pax']
# ['veh_bus_19_in_10:45:00', 'bus_90pax']
# ['veh_bus_19_in_11:00:00', 'bus_90pax']
# ['veh_bus_19_in_11:15:00', 'bus_90pax']
# ['veh_bus_19_in_11:30:00', 'bus_90pax']
# ['veh_bus_19_in_11:45:00', 'bus_90pax']
# ['veh_bus_19_in_12:00:00', 'bus_90pax']
# ['veh_bus_19_in_12:15:00', 'bus_90pax']
# ['veh_bus_19_in_12:30:00', 'bus_90pax']
# ['veh_bus_19_in_12:45:00', 'bus_90pax']
# ['veh_bus_19_in_13:00:00', 'bus_90pax']
# ['veh_bus_19_in_13:15:00', 'bus_90pax']
# ['veh_bus_19_in_13:30:00', 'bus_90pax']
# ['veh_bus_19_in_13:45:00', 'bus_90pax']
# ['veh_bus_19_in_14:00:00', 'bus_90pax']
# ['veh_bus_19_in_14:15:00', 'bus_90pax']
# ['veh_bus_19_in_14:30:00', 'bus_90pax']
# ['veh_bus_19_in_14:45:00', 'bus_90pax']
# ['veh_bus_19_in_15:00:00', 'bus_90pax']
# ['veh_bus_19_in_15:15:00', 'bus_90pax']
# ['veh_bus_19_in_15:30:00', 'bus_90pax']
# ['veh_bus_19_in_15:45:00', 'bus_90pax']
# ['veh_bus_19_in_16:00:00', 'bus_90pax']
# ['veh_bus_19_in_16:15:00', 'bus_90pax']
# ['veh_bus_19_in_16:30:00', 'bus_90pax']
# ['veh_bus_19_in_16:45:00', 'bus_90pax']
# ['veh_bus_19_in_17:00:00', 'bus_90pax']
# ['veh_bus_19_in_17:15:00', 'bus_90pax']
# ['veh_bus_19_in_17:30:00', 'bus_90pax']
# ['veh_bus_19_in_17:45:00', 'bus_90pax']
# ['veh_bus_19_in_18:00:00', 'bus_90pax']
# ['veh_bus_19_in_18:15:00', 'bus_90pax']
# ['veh_bus_19_in_18:30:00', 'bus_90pax']
# ['veh_bus_19_in_18:45:00', 'bus_90pax']
# ['veh_bus_19_in_19:00:00', 'bus_90pax']
# ['veh_bus_19_in_19:15:00', 'bus_90pax']
# ['veh_bus_19_in_19:30:00', 'bus_90pax']
# ['veh_bus_19_in_19:45:00', 'bus_90pax']
# ['veh_bus_19_in_20:00:00', 'bus_90pax']
# ['veh_bus_19_in_20:15:00', 'bus_90pax']
# ['veh_bus_19_in_20:30:00', 'bus_90pax']
# ['veh_bus_19_in_20:45:00', 'bus_90pax']
# ['veh_bus_19_in_21:00:00', 'bus_90pax']
# ['veh_bus_19_in_21:15:00', 'bus_90pax']
# ['veh_bus_19_in_21:30:00', 'bus_90pax']
# ['veh_bus_19_in_21:45:00', 'bus_90pax']
# ['veh_bus_19_in_22:00:00', 'bus_90pax']
# ['veh_bus_19_out_07:00:00', 'bus_90pax']
# ['veh_bus_19_out_07:15:00', 'bus_90pax']
# ['veh_bus_19_out_07:30:00', 'bus_90pax']
# ['veh_bus_19_out_07:45:00', 'bus_90pax']
# ['veh_bus_19_out_08:00:00', 'bus_90pax']
# ['veh_bus_19_out_08:15:00', 'bus_90pax']
# ['veh_bus_19_out_08:30:00', 'bus_90pax']
# ['veh_bus_19_out_08:45:00', 'bus_90pax']
# ['veh_bus_19_out_09:00:00', 'bus_90pax']
# ['veh_bus_19_out_09:15:00', 'bus_90pax']
# ['veh_bus_19_out_09:30:00', 'bus_90pax']
# ['veh_bus_19_out_09:45:00', 'bus_90pax']
# ['veh_bus_19_out_10:00:00', 'bus_90pax']
# ['veh_bus_19_out_10:15:00', 'bus_90pax']
# ['veh_bus_19_out_10:30:00', 'bus_90pax']
# ['veh_bus_19_out_10:45:00', 'bus_90pax']
# ['veh_bus_19_out_11:00:00', 'bus_90pax']
# ['veh_bus_19_out_11:15:00', 'bus_90pax']
# ['veh_bus_19_out_11:30:00', 'bus_90pax']
# ['veh_bus_19_out_11:45:00', 'bus_90pax']
# ['veh_bus_19_out_12:00:00', 'bus_90pax']
# ['veh_bus_19_out_12:15:00', 'bus_90pax']
# ['veh_bus_19_out_12:30:00', 'bus_90pax']
# ['veh_bus_19_out_12:45:00', 'bus_90pax']
# ['veh_bus_19_out_13:00:00', 'bus_90pax']
# ['veh_bus_19_out_13:15:00', 'bus_90pax']
# ['veh_bus_19_out_13:30:00', 'bus_90pax']
# ['veh_bus_19_out_13:45:00', 'bus_90pax']
# ['veh_bus_19_out_14:00:00', 'bus_90pax']
# ['veh_bus_19_out_14:15:00', 'bus_90pax']
# ['veh_bus_19_out_14:30:00', 'bus_90pax']
# ['veh_bus_19_out_14:45:00', 'bus_90pax']
# ['veh_bus_19_out_15:00:00', 'bus_90pax']
# ['veh_bus_19_out_15:15:00', 'bus_90pax']
# ['veh_bus_19_out_15:30:00', 'bus_90pax']
# ['veh_bus_19_out_15:45:00', 'bus_90pax']
# ['veh_bus_19_out_16:00:00', 'bus_90pax']
# ['veh_bus_19_out_16:15:00', 'bus_90pax']
# ['veh_bus_19_out_16:30:00', 'bus_90pax']
# ['veh_bus_19_out_16:45:00', 'bus_90pax']
# ['veh_bus_19_out_17:00:00', 'bus_90pax']
# ['veh_bus_19_out_17:15:00', 'bus_90pax']
# ['veh_bus_19_out_17:30:00', 'bus_90pax']
# ['veh_bus_19_out_17:45:00', 'bus_90pax']
# ['veh_bus_19_out_18:00:00', 'bus_90pax']
# ['veh_bus_19_out_18:15:00', 'bus_90pax']
# ['veh_bus_19_out_18:30:00', 'bus_90pax']
# ['veh_bus_19_out_18:45:00', 'bus_90pax']
# ['veh_bus_19_out_19:00:00', 'bus_90pax']
# ['veh_bus_19_out_19:15:00', 'bus_90pax']
# ['veh_bus_19_out_19:30:00', 'bus_90pax']
# ['veh_bus_19_out_19:45:00', 'bus_90pax']
# ['veh_bus_19_out_20:00:00', 'bus_90pax']
# ['veh_bus_19_out_20:15:00', 'bus_90pax']
# ['veh_bus_19_out_20:30:00', 'bus_90pax']
# ['veh_bus_19_out_20:45:00', 'bus_90pax']
# ['veh_bus_19_out_21:00:00', 'bus_90pax']
# ['veh_bus_19_out_21:15:00', 'bus_90pax']
# ['veh_bus_19_out_21:30:00', 'bus_90pax']
# ['veh_bus_19_out_21:45:00', 'bus_90pax']
# ['veh_bus_19_out_22:00:00', 'bus_90pax']
# ['veh_bus_20_in_07:00:00', 'bus_90pax']
# ['veh_bus_20_in_07:15:00', 'bus_90pax']
# ['veh_bus_20_in_07:30:00', 'bus_90pax']
# ['veh_bus_20_in_07:45:00', 'bus_90pax']
# ['veh_bus_20_in_08:00:00', 'bus_90pax']
# ['veh_bus_20_in_08:15:00', 'bus_90pax']
# ['veh_bus_20_in_08:30:00', 'bus_90pax']
# ['veh_bus_20_in_08:45:00', 'bus_90pax']
# ['veh_bus_20_in_09:00:00', 'bus_90pax']
# ['veh_bus_20_in_09:15:00', 'bus_90pax']
# ['veh_bus_20_in_09:30:00', 'bus_90pax']
# ['veh_bus_20_in_09:45:00', 'bus_90pax']
# ['veh_bus_20_in_10:00:00', 'bus_90pax']
# ['veh_bus_20_in_10:15:00', 'bus_90pax']
# ['veh_bus_20_in_10:30:00', 'bus_90pax']
# ['veh_bus_20_in_10:45:00', 'bus_90pax']
# ['veh_bus_20_in_11:00:00', 'bus_90pax']
# ['veh_bus_20_in_11:15:00', 'bus_90pax']
# ['veh_bus_20_in_11:30:00', 'bus_90pax']
# ['veh_bus_20_in_11:45:00', 'bus_90pax']
# ['veh_bus_20_in_12:00:00', 'bus_90pax']
# ['veh_bus_20_in_12:15:00', 'bus_90pax']
# ['veh_bus_20_in_12:30:00', 'bus_90pax']
# ['veh_bus_20_in_12:45:00', 'bus_90pax']
# ['veh_bus_20_in_13:00:00', 'bus_90pax']
# ['veh_bus_20_in_13:15:00', 'bus_90pax']
# ['veh_bus_20_in_13:30:00', 'bus_90pax']
# ['veh_bus_20_in_13:45:00', 'bus_90pax']
# ['veh_bus_20_in_14:00:00', 'bus_90pax']
# ['veh_bus_20_in_14:15:00', 'bus_90pax']
# ['veh_bus_20_in_14:30:00', 'bus_90pax']
# ['veh_bus_20_in_14:45:00', 'bus_90pax']
# ['veh_bus_20_in_15:00:00', 'bus_90pax']
# ['veh_bus_20_in_15:15:00', 'bus_90pax']
# ['veh_bus_20_in_15:30:00', 'bus_90pax']
# ['veh_bus_20_in_15:45:00', 'bus_90pax']
# ['veh_bus_20_in_16:00:00', 'bus_90pax']
# ['veh_bus_20_in_16:15:00', 'bus_90pax']
# ['veh_bus_20_in_16:30:00', 'bus_90pax']
# ['veh_bus_20_in_16:45:00', 'bus_90pax']
# ['veh_bus_20_in_17:00:00', 'bus_90pax']
# ['veh_bus_20_in_17:15:00', 'bus_90pax']
# ['veh_bus_20_in_17:30:00', 'bus_90pax']
# ['veh_bus_20_in_17:45:00', 'bus_90pax']
# ['veh_bus_20_in_18:00:00', 'bus_90pax']
# ['veh_bus_20_in_18:15:00', 'bus_90pax']
# ['veh_bus_20_in_18:30:00', 'bus_90pax']
# ['veh_bus_20_in_18:45:00', 'bus_90pax']
# ['veh_bus_20_in_19:00:00', 'bus_90pax']
# ['veh_bus_20_in_19:15:00', 'bus_90pax']
# ['veh_bus_20_in_19:30:00', 'bus_90pax']
# ['veh_bus_20_in_19:45:00', 'bus_90pax']
# ['veh_bus_20_in_20:00:00', 'bus_90pax']
# ['veh_bus_20_in_20:15:00', 'bus_90pax']
# ['veh_bus_20_in_20:30:00', 'bus_90pax']
# ['veh_bus_20_in_20:45:00', 'bus_90pax']
# ['veh_bus_20_in_21:00:00', 'bus_90pax']
# ['veh_bus_20_in_21:15:00', 'bus_90pax']
# ['veh_bus_20_in_21:30:00', 'bus_90pax']
# ['veh_bus_20_in_21:45:00', 'bus_90pax']
# ['veh_bus_20_in_22:00:00', 'bus_90pax']
# ['veh_bus_20_out_07:00:00', 'bus_90pax']
# ['veh_bus_20_out_07:15:00', 'bus_90pax']
# ['veh_bus_20_out_07:30:00', 'bus_90pax']
# ['veh_bus_20_out_07:45:00', 'bus_90pax']
# ['veh_bus_20_out_08:00:00', 'bus_90pax']
# ['veh_bus_20_out_08:15:00', 'bus_90pax']
# ['veh_bus_20_out_08:30:00', 'bus_90pax']
# ['veh_bus_20_out_08:45:00', 'bus_90pax']
# ['veh_bus_20_out_09:00:00', 'bus_90pax']
# ['veh_bus_20_out_09:15:00', 'bus_90pax']
# ['veh_bus_20_out_09:30:00', 'bus_90pax']
# ['veh_bus_20_out_09:45:00', 'bus_90pax']
# ['veh_bus_20_out_10:00:00', 'bus_90pax']
# ['veh_bus_20_out_10:15:00', 'bus_90pax']
# ['veh_bus_20_out_10:30:00', 'bus_90pax']
# ['veh_bus_20_out_10:45:00', 'bus_90pax']
# ['veh_bus_20_out_11:00:00', 'bus_90pax']
# ['veh_bus_20_out_11:15:00', 'bus_90pax']
# ['veh_bus_20_out_11:30:00', 'bus_90pax']
# ['veh_bus_20_out_11:45:00', 'bus_90pax']
# ['veh_bus_20_out_12:00:00', 'bus_90pax']
# ['veh_bus_20_out_12:15:00', 'bus_90pax']
# ['veh_bus_20_out_12:30:00', 'bus_90pax']
# ['veh_bus_20_out_12:45:00', 'bus_90pax']
# ['veh_bus_20_out_13:00:00', 'bus_90pax']
# ['veh_bus_20_out_13:15:00', 'bus_90pax']
# ['veh_bus_20_out_13:30:00', 'bus_90pax']
# ['veh_bus_20_out_13:45:00', 'bus_90pax']
# ['veh_bus_20_out_14:00:00', 'bus_90pax']
# ['veh_bus_20_out_14:15:00', 'bus_90pax']
# ['veh_bus_20_out_14:30:00', 'bus_90pax']
# ['veh_bus_20_out_14:45:00', 'bus_90pax']
# ['veh_bus_20_out_15:00:00', 'bus_90pax']
# ['veh_bus_20_out_15:15:00', 'bus_90pax']
# ['veh_bus_20_out_15:30:00', 'bus_90pax']
# ['veh_bus_20_out_15:45:00', 'bus_90pax']
# ['veh_bus_20_out_16:00:00', 'bus_90pax']
# ['veh_bus_20_out_16:15:00', 'bus_90pax']
# ['veh_bus_20_out_16:30:00', 'bus_90pax']
# ['veh_bus_20_out_16:45:00', 'bus_90pax']
# ['veh_bus_20_out_17:00:00', 'bus_90pax']
# ['veh_bus_20_out_17:15:00', 'bus_90pax']
# ['veh_bus_20_out_17:30:00', 'bus_90pax']
# ['veh_bus_20_out_17:45:00', 'bus_90pax']
# ['veh_bus_20_out_18:00:00', 'bus_90pax']
# ['veh_bus_20_out_18:15:00', 'bus_90pax']
# ['veh_bus_20_out_18:30:00', 'bus_90pax']
# ['veh_bus_20_out_18:45:00', 'bus_90pax']
# ['veh_bus_20_out_19:00:00', 'bus_90pax']
# ['veh_bus_20_out_19:15:00', 'bus_90pax']
# ['veh_bus_20_out_19:30:00', 'bus_90pax']
# ['veh_bus_20_out_19:45:00', 'bus_90pax']
# ['veh_bus_20_out_20:00:00', 'bus_90pax']
# ['veh_bus_20_out_20:15:00', 'bus_90pax']
# ['veh_bus_20_out_20:30:00', 'bus_90pax']
# ['veh_bus_20_out_20:45:00', 'bus_90pax']
# ['veh_bus_20_out_21:00:00', 'bus_90pax']
# ['veh_bus_20_out_21:15:00', 'bus_90pax']
# ['veh_bus_20_out_21:30:00', 'bus_90pax']
# ['veh_bus_20_out_21:45:00', 'bus_90pax']
# ['veh_bus_20_out_22:00:00', 'bus_90pax']
# ['veh_bus_21_in_07:00:00', 'bus_90pax']
# ['veh_bus_21_in_07:15:00', 'bus_90pax']
# ['veh_bus_21_in_07:30:00', 'bus_90pax']
# ['veh_bus_21_in_07:45:00', 'bus_90pax']
# ['veh_bus_21_in_08:00:00', 'bus_90pax']
# ['veh_bus_21_in_08:15:00', 'bus_90pax']
# ['veh_bus_21_in_08:30:00', 'bus_90pax']
# ['veh_bus_21_in_08:45:00', 'bus_90pax']
# ['veh_bus_21_in_09:00:00', 'bus_90pax']
# ['veh_bus_21_in_09:15:00', 'bus_90pax']
# ['veh_bus_21_in_09:30:00', 'bus_90pax']
# ['veh_bus_21_in_09:45:00', 'bus_90pax']
# ['veh_bus_21_in_10:00:00', 'bus_90pax']
# ['veh_bus_21_in_10:15:00', 'bus_90pax']
# ['veh_bus_21_in_10:30:00', 'bus_90pax']
# ['veh_bus_21_in_10:45:00', 'bus_90pax']
# ['veh_bus_21_in_11:00:00', 'bus_90pax']
# ['veh_bus_21_in_11:15:00', 'bus_90pax']
# ['veh_bus_21_in_11:30:00', 'bus_90pax']
# ['veh_bus_21_in_11:45:00', 'bus_90pax']
# ['veh_bus_21_in_12:00:00', 'bus_90pax']
# ['veh_bus_21_in_12:15:00', 'bus_90pax']
# ['veh_bus_21_in_12:30:00', 'bus_90pax']
# ['veh_bus_21_in_12:45:00', 'bus_90pax']
# ['veh_bus_21_in_13:00:00', 'bus_90pax']
# ['veh_bus_21_in_13:15:00', 'bus_90pax']
# ['veh_bus_21_in_13:30:00', 'bus_90pax']
# ['veh_bus_21_in_13:45:00', 'bus_90pax']
# ['veh_bus_21_in_14:00:00', 'bus_90pax']
# ['veh_bus_21_in_14:15:00', 'bus_90pax']
# ['veh_bus_21_in_14:30:00', 'bus_90pax']
# ['veh_bus_21_in_14:45:00', 'bus_90pax']
# ['veh_bus_21_in_15:00:00', 'bus_90pax']
# ['veh_bus_21_in_15:15:00', 'bus_90pax']
# ['veh_bus_21_in_15:30:00', 'bus_90pax']
# ['veh_bus_21_in_15:45:00', 'bus_90pax']
# ['veh_bus_21_in_16:00:00', 'bus_90pax']
# ['veh_bus_21_in_16:15:00', 'bus_90pax']
# ['veh_bus_21_in_16:30:00', 'bus_90pax']
# ['veh_bus_21_in_16:45:00', 'bus_90pax']
# ['veh_bus_21_in_17:00:00', 'bus_90pax']
# ['veh_bus_21_in_17:15:00', 'bus_90pax']
# ['veh_bus_21_in_17:30:00', 'bus_90pax']
# ['veh_bus_21_in_17:45:00', 'bus_90pax']
# ['veh_bus_21_in_18:00:00', 'bus_90pax']
# ['veh_bus_21_in_18:15:00', 'bus_90pax']
# ['veh_bus_21_in_18:30:00', 'bus_90pax']
# ['veh_bus_21_in_18:45:00', 'bus_90pax']
# ['veh_bus_21_in_19:00:00', 'bus_90pax']
# ['veh_bus_21_in_19:15:00', 'bus_90pax']
# ['veh_bus_21_in_19:30:00', 'bus_90pax']
# ['veh_bus_21_in_19:45:00', 'bus_90pax']
# ['veh_bus_21_in_20:00:00', 'bus_90pax']
# ['veh_bus_21_in_20:15:00', 'bus_90pax']
# ['veh_bus_21_in_20:30:00', 'bus_90pax']
# ['veh_bus_21_in_20:45:00', 'bus_90pax']
# ['veh_bus_21_in_21:00:00', 'bus_90pax']
# ['veh_bus_21_in_21:15:00', 'bus_90pax']
# ['veh_bus_21_in_21:30:00', 'bus_90pax']
# ['veh_bus_21_in_21:45:00', 'bus_90pax']
# ['veh_bus_21_in_22:00:00', 'bus_90pax']
# ['veh_bus_21_out_07:00:00', 'bus_90pax']
# ['veh_bus_21_out_07:15:00', 'bus_90pax']
# ['veh_bus_21_out_07:30:00', 'bus_90pax']
# ['veh_bus_21_out_07:45:00', 'bus_90pax']
# ['veh_bus_21_out_08:00:00', 'bus_90pax']
# ['veh_bus_21_out_08:15:00', 'bus_90pax']
# ['veh_bus_21_out_08:30:00', 'bus_90pax']
# ['veh_bus_21_out_08:45:00', 'bus_90pax']
# ['veh_bus_21_out_09:00:00', 'bus_90pax']
# ['veh_bus_21_out_09:15:00', 'bus_90pax']
# ['veh_bus_21_out_09:30:00', 'bus_90pax']
# ['veh_bus_21_out_09:45:00', 'bus_90pax']
# ['veh_bus_21_out_10:00:00', 'bus_90pax']
# ['veh_bus_21_out_10:15:00', 'bus_90pax']
# ['veh_bus_21_out_10:30:00', 'bus_90pax']
# ['veh_bus_21_out_10:45:00', 'bus_90pax']
# ['veh_bus_21_out_11:00:00', 'bus_90pax']
# ['veh_bus_21_out_11:15:00', 'bus_90pax']
# ['veh_bus_21_out_11:30:00', 'bus_90pax']
# ['veh_bus_21_out_11:45:00', 'bus_90pax']
# ['veh_bus_21_out_12:00:00', 'bus_90pax']
# ['veh_bus_21_out_12:15:00', 'bus_90pax']
# ['veh_bus_21_out_12:30:00', 'bus_90pax']
# ['veh_bus_21_out_12:45:00', 'bus_90pax']
# ['veh_bus_21_out_13:00:00', 'bus_90pax']
# ['veh_bus_21_out_13:15:00', 'bus_90pax']
# ['veh_bus_21_out_13:30:00', 'bus_90pax']
# ['veh_bus_21_out_13:45:00', 'bus_90pax']
# ['veh_bus_21_out_14:00:00', 'bus_90pax']
# ['veh_bus_21_out_14:15:00', 'bus_90pax']
# ['veh_bus_21_out_14:30:00', 'bus_90pax']
# ['veh_bus_21_out_14:45:00', 'bus_90pax']
# ['veh_bus_21_out_15:00:00', 'bus_90pax']
# ['veh_bus_21_out_15:15:00', 'bus_90pax']
# ['veh_bus_21_out_15:30:00', 'bus_90pax']
# ['veh_bus_21_out_15:45:00', 'bus_90pax']
# ['veh_bus_21_out_16:00:00', 'bus_90pax']
# ['veh_bus_21_out_16:15:00', 'bus_90pax']
# ['veh_bus_21_out_16:30:00', 'bus_90pax']
# ['veh_bus_21_out_16:45:00', 'bus_90pax']
# ['veh_bus_21_out_17:00:00', 'bus_90pax']
# ['veh_bus_21_out_17:15:00', 'bus_90pax']
# ['veh_bus_21_out_17:30:00', 'bus_90pax']
# ['veh_bus_21_out_17:45:00', 'bus_90pax']
# ['veh_bus_21_out_18:00:00', 'bus_90pax']
# ['veh_bus_21_out_18:15:00', 'bus_90pax']
# ['veh_bus_21_out_18:30:00', 'bus_90pax']
# ['veh_bus_21_out_18:45:00', 'bus_90pax']
# ['veh_bus_21_out_19:00:00', 'bus_90pax']
# ['veh_bus_21_out_19:15:00', 'bus_90pax']
# ['veh_bus_21_out_19:30:00', 'bus_90pax']
# ['veh_bus_21_out_19:45:00', 'bus_90pax']
# ['veh_bus_21_out_20:00:00', 'bus_90pax']
# ['veh_bus_21_out_20:15:00', 'bus_90pax']
# ['veh_bus_21_out_20:30:00', 'bus_90pax']
# ['veh_bus_21_out_20:45:00', 'bus_90pax']
# ['veh_bus_21_out_21:00:00', 'bus_90pax']
# ['veh_bus_21_out_21:15:00', 'bus_90pax']
# ['veh_bus_21_out_21:30:00', 'bus_90pax']
# ['veh_bus_21_out_21:45:00', 'bus_90pax']
# ['veh_bus_21_out_22:00:00', 'bus_90pax']

# %% [markdown]
# ### Xử lý event. Đồng thời nhận thêm zone để quan sát điểm đầu cuối của trip

# %%
# !powershell -Command "Get-Content 'data\\simple_scenario\\output\\output_events.xml' -TotalCount 1000 | ForEach-Object { '{0:5}: {1}' -f $_.ReadCount, $_ }"
# Out:
# 5: <?xml version="1.0" encoding="utf-8"?>
# 5: <events version="1.0">
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Tram_Line_1_dir_fwd_0_tram_type" vehicleId="veh_Tram_Line_1_dir_fwd_0" transitLineId="Tram_Line_1" transitRouteId="dir_fwd" departureId="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Tram_Line_1_dir_fwd_0_tram_type" link="7" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Tram_Line_1_dir_fwd_0_tram_type" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Tram_Line_1_dir_bwd_0_tram_type" vehicleId="veh_Tram_Line_1_dir_bwd_0" transitLineId="Tram_Line_1" transitRouteId="dir_bwd" departureId="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Tram_Line_1_dir_bwd_0_tram_type" link="74" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Tram_Line_1_dir_bwd_0_tram_type" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Train_Line_1_dir_fwd_0_train_type" vehicleId="veh_Train_Line_1_dir_fwd_0" transitLineId="Train_Line_1" transitRouteId="dir_fwd" departureId="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Train_Line_1_dir_fwd_0_train_type" link="19" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Train_Line_1_dir_fwd_0_train_type" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Train_Line_1_dir_bwd_0_train_type" vehicleId="veh_Train_Line_1_dir_bwd_0" transitLineId="Train_Line_1" transitRouteId="dir_bwd" departureId="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Train_Line_1_dir_bwd_0_train_type" link="86" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Train_Line_1_dir_bwd_0_train_type" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_3_dir_fwd_0_bus_type" vehicleId="veh_Bus_Line_3_dir_fwd_0" transitLineId="Bus_Line_3" transitRouteId="dir_fwd" departureId="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Bus_Line_3_dir_fwd_0_bus_type" link="89" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_3_dir_fwd_0_bus_type" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_3_dir_bwd_0_bus_type" vehicleId="veh_Bus_Line_3_dir_bwd_0" transitLineId="Bus_Line_3" transitRouteId="dir_bwd" departureId="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Bus_Line_3_dir_bwd_0_bus_type" link="98" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_3_dir_bwd_0_bus_type" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_2_dir_fwd_0_bus_type" vehicleId="veh_Bus_Line_2_dir_fwd_0" transitLineId="Bus_Line_2" transitRouteId="dir_fwd" departureId="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Bus_Line_2_dir_fwd_0_bus_type" link="45" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_2_dir_fwd_0_bus_type" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_2_dir_bwd_0_bus_type" vehicleId="veh_Bus_Line_2_dir_bwd_0" transitLineId="Bus_Line_2" transitRouteId="dir_bwd" departureId="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Bus_Line_2_dir_bwd_0_bus_type" link="62" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_2_dir_bwd_0_bus_type" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_1_dir_fwd_0_bus_type" vehicleId="veh_Bus_Line_1_dir_fwd_0" transitLineId="Bus_Line_1" transitRouteId="dir_fwd" departureId="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Bus_Line_1_dir_fwd_0_bus_type" link="1" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_1_dir_fwd_0_bus_type" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21600.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_1_dir_bwd_0_bus_type" vehicleId="veh_Bus_Line_1_dir_bwd_0" transitLineId="Bus_Line_1" transitRouteId="dir_bwd" departureId="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="departure" person="pt_veh_Bus_Line_1_dir_bwd_0_bus_type" link="18" legMode="car"  />
# 5: 	<event time="21600.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_1_dir_bwd_0_bus_type" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Tram_Line_1_dir_fwd_0_tram_type" link="7" vehicle="veh_Tram_Line_1_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_7" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_7" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Tram_Line_1_dir_bwd_0_tram_type" link="74" vehicle="veh_Tram_Line_1_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_74" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_74" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Train_Line_1_dir_fwd_0_train_type" link="19" vehicle="veh_Train_Line_1_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_19" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_19" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Train_Line_1_dir_bwd_0_train_type" link="86" vehicle="veh_Train_Line_1_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_86" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_86" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Bus_Line_3_dir_fwd_0_bus_type" link="89" vehicle="veh_Bus_Line_3_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_89" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_89" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Bus_Line_3_dir_bwd_0_bus_type" link="98" vehicle="veh_Bus_Line_3_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_98" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_98" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Bus_Line_2_dir_fwd_0_bus_type" link="45" vehicle="veh_Bus_Line_2_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_45" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_45" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Bus_Line_2_dir_bwd_0_bus_type" link="62" vehicle="veh_Bus_Line_2_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_62" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_62" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Bus_Line_1_dir_fwd_0_bus_type" link="1" vehicle="veh_Bus_Line_1_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_1" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_1" delay="0.0"  />
# 5: 	<event time="21600.0" type="vehicle enters traffic" person="pt_veh_Bus_Line_1_dir_bwd_0_bus_type" link="18" vehicle="veh_Bus_Line_1_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="21600.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_18" delay="0.0"  />
# 5: 	<event time="21600.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_18" delay="0.0"  />
# 5: 	<event time="21601.0" type="left link" link="7" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="29" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="74" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="52" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="19" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="41" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="86" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="64" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="89" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="91" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="98" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="96" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="45" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="49" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="62" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="58" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="1" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="5" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21601.0" type="left link" link="18" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="21601.0" type="entered link" link="14" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_29" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_29" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_52" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_52" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_41" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_41" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_64" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_64" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_91" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_91" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_96" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_96" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_49" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_49" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_58" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_58" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_5" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_5" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_14" delay="136.0"  />
# 5: 	<event time="21736.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_14" delay="136.0"  />
# 5: 	<event time="21737.0" type="left link" link="52" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="30" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="29" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="51" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="64" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="42" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="41" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="63" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="91" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="93" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="96" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="94" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="49" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="53" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="58" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="54" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="5" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="9" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21737.0" type="left link" link="14" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="21737.0" type="entered link" link="10" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_30" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_30" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_51" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_51" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_42" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_42" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_63" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_63" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_93" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_93" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_94" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_94" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_53" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_53" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_54" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_54" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_9" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_9" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_10" delay="272.0"  />
# 5: 	<event time="21872.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_10" delay="272.0"  />
# 5: 	<event time="21873.0" type="left link" link="30" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="8" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="51" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="73" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="42" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="20" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="63" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="85" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="93" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="95" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="94" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="92" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="53" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="57" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="54" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="50" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="9" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="13" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="21873.0" type="left link" link="10" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="21873.0" type="entered link" link="6" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_8" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_bwd_0" facility="stop_8" delay="408.0"  />
# 5: 	<event time="22008.0" type="vehicle leaves traffic" person="pt_veh_Tram_Line_1_dir_bwd_0_tram_type" link="8" vehicle="veh_Tram_Line_1_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22008.0" type="PersonLeavesVehicle" person="pt_veh_Tram_Line_1_dir_bwd_0_tram_type" vehicle="veh_Tram_Line_1_dir_bwd_0"  />
# 5: 	<event time="22008.0" type="arrival" person="pt_veh_Tram_Line_1_dir_bwd_0_tram_type" link="8" legMode="car"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_73" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Tram_Line_1_dir_fwd_0" facility="stop_73" delay="408.0"  />
# 5: 	<event time="22008.0" type="vehicle leaves traffic" person="pt_veh_Tram_Line_1_dir_fwd_0_tram_type" link="73" vehicle="veh_Tram_Line_1_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22008.0" type="PersonLeavesVehicle" person="pt_veh_Tram_Line_1_dir_fwd_0_tram_type" vehicle="veh_Tram_Line_1_dir_fwd_0"  />
# 5: 	<event time="22008.0" type="arrival" person="pt_veh_Tram_Line_1_dir_fwd_0_tram_type" link="73" legMode="car"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_20" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_bwd_0" facility="stop_20" delay="408.0"  />
# 5: 	<event time="22008.0" type="vehicle leaves traffic" person="pt_veh_Train_Line_1_dir_bwd_0_train_type" link="20" vehicle="veh_Train_Line_1_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22008.0" type="PersonLeavesVehicle" person="pt_veh_Train_Line_1_dir_bwd_0_train_type" vehicle="veh_Train_Line_1_dir_bwd_0"  />
# 5: 	<event time="22008.0" type="arrival" person="pt_veh_Train_Line_1_dir_bwd_0_train_type" link="20" legMode="car"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_85" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Train_Line_1_dir_fwd_0" facility="stop_85" delay="408.0"  />
# 5: 	<event time="22008.0" type="vehicle leaves traffic" person="pt_veh_Train_Line_1_dir_fwd_0_train_type" link="85" vehicle="veh_Train_Line_1_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22008.0" type="PersonLeavesVehicle" person="pt_veh_Train_Line_1_dir_fwd_0_train_type" vehicle="veh_Train_Line_1_dir_fwd_0"  />
# 5: 	<event time="22008.0" type="arrival" person="pt_veh_Train_Line_1_dir_fwd_0_train_type" link="85" legMode="car"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_95" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_95" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_92" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_92" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_57" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_57" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_50" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_50" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_13" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_13" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_6" delay="408.0"  />
# 5: 	<event time="22008.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_6" delay="408.0"  />
# 5: 	<event time="22009.0" type="left link" link="95" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="22009.0" type="entered link" link="97" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="22009.0" type="left link" link="92" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="22009.0" type="entered link" link="90" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="22009.0" type="left link" link="57" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="22009.0" type="entered link" link="61" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="22009.0" type="left link" link="50" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="22009.0" type="entered link" link="46" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="22009.0" type="left link" link="13" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="22009.0" type="entered link" link="17" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="22009.0" type="left link" link="6" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="22009.0" type="entered link" link="2" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="22144.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_97" delay="544.0"  />
# 5: 	<event time="22144.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_fwd_0" facility="stop_97" delay="544.0"  />
# 5: 	<event time="22144.0" type="vehicle leaves traffic" person="pt_veh_Bus_Line_3_dir_fwd_0_bus_type" link="97" vehicle="veh_Bus_Line_3_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22144.0" type="PersonLeavesVehicle" person="pt_veh_Bus_Line_3_dir_fwd_0_bus_type" vehicle="veh_Bus_Line_3_dir_fwd_0"  />
# 5: 	<event time="22144.0" type="arrival" person="pt_veh_Bus_Line_3_dir_fwd_0_bus_type" link="97" legMode="car"  />
# 5: 	<event time="22144.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_90" delay="544.0"  />
# 5: 	<event time="22144.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_3_dir_bwd_0" facility="stop_90" delay="544.0"  />
# 5: 	<event time="22144.0" type="vehicle leaves traffic" person="pt_veh_Bus_Line_3_dir_bwd_0_bus_type" link="90" vehicle="veh_Bus_Line_3_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22144.0" type="PersonLeavesVehicle" person="pt_veh_Bus_Line_3_dir_bwd_0_bus_type" vehicle="veh_Bus_Line_3_dir_bwd_0"  />
# 5: 	<event time="22144.0" type="arrival" person="pt_veh_Bus_Line_3_dir_bwd_0_bus_type" link="90" legMode="car"  />
# 5: 	<event time="22144.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_61" delay="544.0"  />
# 5: 	<event time="22144.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_fwd_0" facility="stop_61" delay="544.0"  />
# 5: 	<event time="22144.0" type="vehicle leaves traffic" person="pt_veh_Bus_Line_2_dir_fwd_0_bus_type" link="61" vehicle="veh_Bus_Line_2_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22144.0" type="PersonLeavesVehicle" person="pt_veh_Bus_Line_2_dir_fwd_0_bus_type" vehicle="veh_Bus_Line_2_dir_fwd_0"  />
# 5: 	<event time="22144.0" type="arrival" person="pt_veh_Bus_Line_2_dir_fwd_0_bus_type" link="61" legMode="car"  />
# 5: 	<event time="22144.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_46" delay="544.0"  />
# 5: 	<event time="22144.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_2_dir_bwd_0" facility="stop_46" delay="544.0"  />
# 5: 	<event time="22144.0" type="vehicle leaves traffic" person="pt_veh_Bus_Line_2_dir_bwd_0_bus_type" link="46" vehicle="veh_Bus_Line_2_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22144.0" type="PersonLeavesVehicle" person="pt_veh_Bus_Line_2_dir_bwd_0_bus_type" vehicle="veh_Bus_Line_2_dir_bwd_0"  />
# 5: 	<event time="22144.0" type="arrival" person="pt_veh_Bus_Line_2_dir_bwd_0_bus_type" link="46" legMode="car"  />
# 5: 	<event time="22144.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_17" delay="544.0"  />
# 5: 	<event time="22144.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_fwd_0" facility="stop_17" delay="544.0"  />
# 5: 	<event time="22144.0" type="vehicle leaves traffic" person="pt_veh_Bus_Line_1_dir_fwd_0_bus_type" link="17" vehicle="veh_Bus_Line_1_dir_fwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22144.0" type="PersonLeavesVehicle" person="pt_veh_Bus_Line_1_dir_fwd_0_bus_type" vehicle="veh_Bus_Line_1_dir_fwd_0"  />
# 5: 	<event time="22144.0" type="arrival" person="pt_veh_Bus_Line_1_dir_fwd_0_bus_type" link="17" legMode="car"  />
# 5: 	<event time="22144.0" type="VehicleArrivesAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_2" delay="544.0"  />
# 5: 	<event time="22144.0" type="VehicleDepartsAtFacility" vehicle="veh_Bus_Line_1_dir_bwd_0" facility="stop_2" delay="544.0"  />
# 5: 	<event time="22144.0" type="vehicle leaves traffic" person="pt_veh_Bus_Line_1_dir_bwd_0_bus_type" link="2" vehicle="veh_Bus_Line_1_dir_bwd_0" networkMode="car" relativePosition="1.0"  />
# 5: 	<event time="22144.0" type="PersonLeavesVehicle" person="pt_veh_Bus_Line_1_dir_bwd_0_bus_type" vehicle="veh_Bus_Line_1_dir_bwd_0"  />
# 5: 	<event time="22144.0" type="arrival" person="pt_veh_Bus_Line_1_dir_bwd_0_bus_type" link="2" legMode="car"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Tram_Line_1_dir_fwd_1_tram_type" vehicleId="veh_Tram_Line_1_dir_fwd_1" transitLineId="Tram_Line_1" transitRouteId="dir_fwd" departureId="veh_Tram_Line_1_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Tram_Line_1_dir_fwd_1_tram_type" link="7" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Tram_Line_1_dir_fwd_1_tram_type" vehicle="veh_Tram_Line_1_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Tram_Line_1_dir_bwd_1_tram_type" vehicleId="veh_Tram_Line_1_dir_bwd_1" transitLineId="Tram_Line_1" transitRouteId="dir_bwd" departureId="veh_Tram_Line_1_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Tram_Line_1_dir_bwd_1_tram_type" link="74" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Tram_Line_1_dir_bwd_1_tram_type" vehicle="veh_Tram_Line_1_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Train_Line_1_dir_fwd_1_train_type" vehicleId="veh_Train_Line_1_dir_fwd_1" transitLineId="Train_Line_1" transitRouteId="dir_fwd" departureId="veh_Train_Line_1_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Train_Line_1_dir_fwd_1_train_type" link="19" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Train_Line_1_dir_fwd_1_train_type" vehicle="veh_Train_Line_1_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Train_Line_1_dir_bwd_1_train_type" vehicleId="veh_Train_Line_1_dir_bwd_1" transitLineId="Train_Line_1" transitRouteId="dir_bwd" departureId="veh_Train_Line_1_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Train_Line_1_dir_bwd_1_train_type" link="86" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Train_Line_1_dir_bwd_1_train_type" vehicle="veh_Train_Line_1_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_3_dir_fwd_1_bus_type" vehicleId="veh_Bus_Line_3_dir_fwd_1" transitLineId="Bus_Line_3" transitRouteId="dir_fwd" departureId="veh_Bus_Line_3_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Bus_Line_3_dir_fwd_1_bus_type" link="89" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_3_dir_fwd_1_bus_type" vehicle="veh_Bus_Line_3_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_3_dir_bwd_1_bus_type" vehicleId="veh_Bus_Line_3_dir_bwd_1" transitLineId="Bus_Line_3" transitRouteId="dir_bwd" departureId="veh_Bus_Line_3_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Bus_Line_3_dir_bwd_1_bus_type" link="98" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_3_dir_bwd_1_bus_type" vehicle="veh_Bus_Line_3_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_2_dir_fwd_1_bus_type" vehicleId="veh_Bus_Line_2_dir_fwd_1" transitLineId="Bus_Line_2" transitRouteId="dir_fwd" departureId="veh_Bus_Line_2_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Bus_Line_2_dir_fwd_1_bus_type" link="45" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_2_dir_fwd_1_bus_type" vehicle="veh_Bus_Line_2_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_2_dir_bwd_1_bus_type" vehicleId="veh_Bus_Line_2_dir_bwd_1" transitLineId="Bus_Line_2" transitRouteId="dir_bwd" departureId="veh_Bus_Line_2_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Bus_Line_2_dir_bwd_1_bus_type" link="62" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_2_dir_bwd_1_bus_type" vehicle="veh_Bus_Line_2_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_1_dir_fwd_1_bus_type" vehicleId="veh_Bus_Line_1_dir_fwd_1" transitLineId="Bus_Line_1" transitRouteId="dir_fwd" departureId="veh_Bus_Line_1_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Bus_Line_1_dir_fwd_1_bus_type" link="1" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_1_dir_fwd_1_bus_type" vehicle="veh_Bus_Line_1_dir_fwd_1"  />
# 5: 	<event time="25200.0" type="TransitDriverStarts" driverId="pt_veh_Bus_Line_1_dir_bwd_1_bus_type" vehicleId="veh_Bus_Line_1_dir_bwd_1" transitLineId="Bus_Line_1" transitRouteId="dir_bwd" departureId="veh_Bus_Line_1_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="departure" person="pt_veh_Bus_Line_1_dir_bwd_1_bus_type" link="18" legMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="pt_veh_Bus_Line_1_dir_bwd_1_bus_type" vehicle="veh_Bus_Line_1_dir_bwd_1"  />
# 5: 	<event time="25200.0" type="actend" person="p_99" link="55" x="467004.49691711005" y="5747312.61476943" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_99" link="55" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_99" vehicle="p_99"  />
# 5: 	<event time="25200.0" type="actend" person="p_98" link="83" x="474838.8979144604" y="5749112.584238095" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_98" link="83" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_98" vehicle="p_98"  />
# 5: 	<event time="25200.0" type="actend" person="p_97" link="61" x="474222.5176194209" y="5745902.266420322" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_97" link="61" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_96" link="55" x="466011.9573024381" y="5748694.530387398" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_96" link="55" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_95" link="55" x="466228.3605157719" y="5746464.960124816" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_95" link="55" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_95" vehicle="p_95"  />
# 5: 	<event time="25200.0" type="actend" person="p_94" link="95" x="469387.04332205275" y="5751700.176085868" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_94" link="95" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_93" link="5" x="464273.1588324972" y="5740096.440546444" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_93" link="5" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_92" link="11" x="466204.0083923909" y="5741686.570403985" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_92" link="11" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_91" link="27" x="464487.85268462874" y="5743047.779884524" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_91" link="27" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_91" vehicle="p_91"  />
# 5: 	<event time="25200.0" type="actend" person="p_90" link="49" x="465636.3964396261" y="5746002.383162255" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_90" link="49" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_9" link="67" x="461527.84674932586" y="5750149.4577558255" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_9" link="67" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_89" link="59" x="468824.74625906267" y="5748123.866407136" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_89" link="59" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_89" vehicle="p_89"  />
# 5: 	<event time="25200.0" type="actend" person="p_88" link="93" x="468061.4660213229" y="5751722.4371011155" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_88" link="93" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_88" vehicle="p_88"  />
# 5: 	<event time="25200.0" type="actend" person="p_87" link="37" x="469234.74067900435" y="5744624.776896999" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_87" link="37" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_86" link="85" x="472811.0387381282" y="5750771.462452838" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_86" link="85" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_86" vehicle="p_86"  />
# 5: 	<event time="25200.0" type="actend" person="p_85" link="15" x="468724.35575137683" y="5741042.355327567" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_85" link="15" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_84" link="47" x="460457.9692953628" y="5747644.097732253" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_84" link="47" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_84" vehicle="p_84"  />
# 5: 	<event time="25200.0" type="actend" person="p_83" link="81" x="469367.555229604" y="5750100.635672837" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_83" link="81" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_83" vehicle="p_83"  />
# 5: 	<event time="25200.0" type="actend" person="p_82" link="29" x="463446.8376312064" y="5744802.868338566" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_82" link="29" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_82" vehicle="p_82"  />
# 5: 	<event time="25200.0" type="actend" person="p_81" link="45" x="461301.3534051723" y="5745832.920313041" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_81" link="45" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_80" link="81" x="469682.8727148869" y="5750890.3990036575" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_80" link="81" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_80" vehicle="p_80"  />
# 5: 	<event time="25200.0" type="actend" person="p_8" link="51" x="461663.15360757505" y="5747616.762781579" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_8" link="51" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_79" link="41" x="471352.586584099" y="5744859.298411943" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_79" link="41" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_79" vehicle="p_79"  />
# 5: 	<event time="25200.0" type="actend" person="p_78" link="91" x="464966.02077159384" y="5751339.278584843" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_78" link="91" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_78" vehicle="p_78"  />
# 5: 	<event time="25200.0" type="actend" person="p_77" link="21" x="474295.06408412947" y="5742060.688467907" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_77" link="21" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_76" link="10" x="468286.31341939076" y="5740313.592335386" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_76" link="10" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_75" link="81" x="468402.6489476891" y="5750248.194368349" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_75" link="81" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_74" link="71" x="465246.2026263855" y="5749680.445057248" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_74" link="71" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_73" link="25" x="460897.8383250505" y="5744956.627120524" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_73" link="25" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_72" link="75" x="467258.51546812494" y="5749921.277588579" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_72" link="75" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_71" link="25" x="460314.00315766956" y="5745599.639767264" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_71" link="25" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_70" link="7" x="461987.5692688564" y="5741549.121874543" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_70" link="7" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_70" vehicle="p_70"  />
# 5: 	<event time="25200.0" type="actend" person="p_7" link="37" x="468918.1292033522" y="5745817.1363401385" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_7" link="37" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_69" link="19" x="471652.00881671265" y="5740386.216276039" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_69" link="19" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_68" link="29" x="463417.5090125116" y="5744233.311053166" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_68" link="29" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_67" link="73" x="462112.6696147127" y="5750119.987130482" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_67" link="73" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_66" link="91" x="465346.24593984755" y="5751458.968489482" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_66" link="91" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_66" vehicle="p_66"  />
# 5: 	<event time="25200.0" type="actend" person="p_65" link="91" x="465061.10313470225" y="5751316.443004146" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_65" link="91" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_65" vehicle="p_65"  />
# 5: 	<event time="25200.0" type="actend" person="p_64" link="57" x="470871.99673344544" y="5745028.321019791" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_64" link="57" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_64" vehicle="p_64"  />
# 5: 	<event time="25200.0" type="actend" person="p_63" link="13" x="469378.93286922364" y="5740137.363145698" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_63" link="13" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_62" link="73" x="462644.5065565727" y="5749566.46008154" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_62" link="73" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_61" link="77" x="466122.0283293921" y="5750800.597474653" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_61" link="77" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_60" link="31" x="467570.7141330582" y="5743748.477655943" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_60" link="31" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_6" link="49" x="465425.31884779956" y="5745632.138804941" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_6" link="49" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_59" link="41" x="472134.18374528096" y="5745819.890243016" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_59" link="41" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_59" vehicle="p_59"  />
# 5: 	<event time="25200.0" type="actend" person="p_58" link="37" x="469570.0229041518" y="5743857.979529576" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_58" link="37" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_57" link="97" x="473449.1357165133" y="5751397.677066233" actType="home"  />
# ...
# 5: 	<event time="25200.0" type="departure" person="p_312" link="95" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_312" vehicle="p_312"  />
# 5: 	<event time="25200.0" type="actend" person="p_311" link="3" x="460212.59693654114" y="5742136.004119965" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_311" link="3" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_310" link="7" x="463651.44280163106" y="5742238.506897172" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_310" link="7" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_31" link="65" x="474347.6549457985" y="5746797.183397448" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_31" link="65" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_31" vehicle="p_31"  />
# 5: 	<event time="25200.0" type="actend" person="p_309" link="39" x="473434.6752734082" y="5742135.207320409" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_309" link="39" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_309" vehicle="p_309"  />
# 5: 	<event time="25200.0" type="actend" person="p_308" link="55" x="465234.04669587314" y="5747850.715624678" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_308" link="55" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_308" vehicle="p_308"  />
# 5: 	<event time="25200.0" type="actend" person="p_307" link="25" x="460462.4052212296" y="5744523.267641489" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_307" link="25" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_307" vehicle="p_307"  />
# 5: 	<event time="25200.0" type="actend" person="p_306" link="35" x="469525.5159199125" y="5742651.288095466" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_306" link="35" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_305" link="69" x="460322.16539275885" y="5751093.422135549" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_305" link="69" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_304" link="23" x="460811.9556441085" y="5742756.124360237" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_304" link="23" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_303" link="21" x="474164.500073962" y="5741307.509538059" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_303" link="21" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_302" link="13" x="471585.4714876653" y="5740176.690436613" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_302" link="13" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_301" link="45" x="461681.37269323436" y="5746753.6930462215" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_301" link="45" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_301" vehicle="p_301"  />
# 5: 	<event time="25200.0" type="actend" person="p_300" link="77" x="466069.0320203965" y="5751672.685707726" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_300" link="77" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_30" link="1" x="462082.92389518226" y="5740124.11830017" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_30" link="1" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_3" link="51" x="462352.97559227364" y="5747003.685604617" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_3" link="51" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_3" vehicle="p_3"  />
# 5: 	<event time="25200.0" type="actend" person="p_299" link="53" x="468371.76472588425" y="5746110.577016559" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_299" link="53" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_298" link="17" x="473687.00220423937" y="5740047.6598389745" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_298" link="17" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_297" link="39" x="473132.9220106209" y="5742221.141036121" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_297" link="39" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_296" link="71" x="464390.230177179" y="5748260.908173703" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_296" link="71" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_296" vehicle="p_296"  />
# 5: 	<event time="25200.0" type="actend" person="p_295" link="69" x="460737.66590328177" y="5750289.808360961" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_295" link="69" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_294" link="27" x="464361.78322803386" y="5742520.013598646" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_294" link="27" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_294" vehicle="p_294"  />
# 5: 	<event time="25200.0" type="actend" person="p_293" link="35" x="470963.2057385431" y="5742902.1605516765" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_293" link="35" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_293" vehicle="p_293"  />
# 5: 	<event time="25200.0" type="actend" person="p_292" link="51" x="461995.3407629374" y="5747508.464220934" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_292" link="51" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_291" link="81" x="468583.96574978245" y="5749974.908993586" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_291" link="81" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_290" link="59" x="468607.9338544952" y="5747485.677266592" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_290" link="59" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_29" link="85" x="472166.5059886006" y="5749940.454940401" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_29" link="85" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_29" vehicle="p_29"  />
# 5: 	<event time="25200.0" type="actend" person="p_289" link="73" x="463212.9023347401" y="5749798.912122442" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_289" link="73" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_288" link="13" x="470673.9820334501" y="5740570.829917912" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_288" link="13" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_287" link="3" x="460830.3445877082" y="5742148.226311446" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_287" link="3" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_286" link="73" x="463153.3016018662" y="5749619.20041699" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_286" link="73" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_285" link="21" x="474975.4409247236" y="5741447.43283285" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_285" link="21" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_284" link="63" x="472222.35797660926" y="5746391.22369936" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_284" link="63" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_283" link="5" x="464474.8239149582" y="5741286.450046368" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_283" link="5" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_282" link="77" x="465622.93538511003" y="5750848.022458965" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_282" link="77" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_281" link="67" x="461240.2578121709" y="5749554.639603573" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_281" link="67" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_281" vehicle="p_281"  />
# 5: 	<event time="25200.0" type="actend" person="p_280" link="41" x="472348.67369457945" y="5744417.280524714" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_280" link="41" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_280" vehicle="p_280"  />
# 5: 	<event time="25200.0" type="actend" person="p_28" link="3" x="460744.6431702426" y="5741358.217655427" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_28" link="3" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_279" link="67" x="462378.8882488357" y="5749344.243270234" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_279" link="67" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_278" link="93" x="466986.7789900129" y="5751758.96591416" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_278" link="93" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_277" link="57" x="470383.26136935083" y="5745834.979405917" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_277" link="57" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_277" vehicle="p_277"  />
# 5: 	<event time="25200.0" type="actend" person="p_276" link="73" x="461905.6364334594" y="5750667.965589663" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_276" link="73" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_275" link="31" x="468449.47076568264" y="5742773.493405523" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_275" link="31" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_274" link="17" x="473992.184132756" y="5740125.32214941" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_274" link="17" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_274" vehicle="p_274"  />
# 5: 	<event time="25200.0" type="actend" person="p_273" link="49" x="464710.5998470075" y="5745563.869545939" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_273" link="49" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_272" link="27" x="464901.1056119833" y="5743143.567680549" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_272" link="27" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_271" link="19" x="472093.5577766691" y="5741527.601218784" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_271" link="19" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_270" link="83" x="472644.09632166405" y="5748702.859632463" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_270" link="83" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_27" link="10" x="466689.9667123122" y="5740343.924253939" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_27" link="10" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_269" link="85" x="471581.1807216739" y="5751364.451188171" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_269" link="85" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_268" link="19" x="471738.4682389602" y="5741585.905797206" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_268" link="19" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_267" link="39" x="473956.62087163044" y="5742857.408896858" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_267" link="39" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_267" vehicle="p_267"  />
# 5: 	<event time="25200.0" type="actend" person="p_266" link="79" x="470754.13610186806" y="5750053.427350109" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_266" link="79" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_265" link="55" x="466457.2016838193" y="5747006.738554515" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_265" link="55" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_264" link="71" x="465395.9241910784" y="5749138.247461007" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_264" link="71" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_263" link="23" x="462143.51396196475" y="5742626.795104614" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_263" link="23" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_263" vehicle="p_263"  />
# 5: 	<event time="25200.0" type="actend" person="p_262" link="29" x="464192.0543178049" y="5744799.3620219575" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_262" link="29" legMode="walk" computationalRoutingMode="pt"  />
# 5: 	<event time="25200.0" type="actend" person="p_261" link="81" x="468709.493029985" y="5751213.648079315" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_261" link="81" legMode="car" computationalRoutingMode="car"  />
# 5: 	<event time="25200.0" type="PersonEntersVehicle" person="p_261" vehicle="p_261"  />
# 5: 	<event time="25200.0" type="actend" person="p_260" link="33" x="465428.39130238746" y="5744341.652741143" actType="home"  />
# 5: 	<event time="25200.0" type="departure" person="p_260" link="33" legMode="walk" computationalRoutingMode="pt"  />

# %% [markdown]
# #3.1 Chỉ đếm những người lên xe bus khác lái xe

# %%
hint_bus_type = "bus"
schema = ['vehIdList', 'vehicleTypeList', 'mainMode' , 'travelTime', 'OZone', 'DZone', 'actstart', 'actend', 'xO', 'yO', 'xD', 'yD', 'startTime']
person_trip_map = {}
simple_zones : list[Zone]= generate_checkerboard_shape_zone_from_network(NETWORK_PATH, 20, 20)

with open(OUTPUT_EVENT_AFTER_PROCESSOR, 'a') as f:
    for x in schema[:-1]:
        f.write(x + ",")
    f.write(schema[-1] + "\n")

context = etree.iterparse(EVENT_PATH, events=('end',))
for event, elem in context:
    if elem.tag == "event":
        e_type = elem.get("type")

        if e_type == "actend":
            personId = elem.get("person")

            if personId in person_trip_map.keys():
                continue
            if personId.startswith("pt_"):
                continue
            if elem.get("actType") == "pt interaction":
                continue

            actstart = elem.get("actType")
            
            x = float(elem.get("x"))
            y = float(elem.get("y"))
            person_location = Point(x, y)
            in_zone_id = "undefined"
            for zone in simple_zones:
                if zone.is_in_zone(person_location):
                    in_zone_id = zone.zone_id
                    break

            person_trip_map[personId] = {
                "actstart" : actstart,
                "OZone": in_zone_id,
                "xO": x,
                "yO": y
                }


        elif e_type == "departure":
            personId = elem.get("person")

            # Nếu trip của người này đã được ghi nhận trước đó và chưa kết thúc thì bỏ qua
            if personId in person_trip_map.keys():
                if "vehIdList" not in person_trip_map[personId].keys():
                    person_trip_map[personId]["vehIdList"] = []
                    person_trip_map[personId]["vehicleTypeList"] = []
                    person_trip_map[personId]["mainMode"] =  elem.get("computationalRoutingMode")
                    person_trip_map[personId]["startTime"] = float(elem.get("time"))
                

        elif e_type == "PersonEntersVehicle":
            personId = elem.get("person")
            veh_id = elem.get("vehicle")

            if personId not in person_trip_map.keys():
                continue
            if personId.startswith("pt_"):
                continue
                
            person_trip_map[personId]["vehIdList"].append(veh_id)

            if veh_id in vehtype_dict.keys():
                person_trip_map[personId]["vehicleTypeList"].append(vehtype_dict[veh_id])
            else :
                person_trip_map[personId]["vehicleTypeList"].append("undefined")


        elif e_type == "actstart":
            personId = elem.get("person")

            if personId not in person_trip_map.keys():
                continue
            if personId.startswith("pt_"):
                continue
            if elem.get("actType") == "pt interaction":
                continue
        
            person_trip_map[personId]["travelTime"] = float(elem.get("time")) - person_trip_map[personId]["startTime"]
            person_trip_map[personId]["actend"] = elem.get("actType")

            # Xác định vùng DZone chứa ddierm cuối của trip
            xD = float(elem.get("x"))
            yD = float(elem.get("y"))
            person_location = Point(xD, yD)
            in_zone_id = "undefined"
            for zone in simple_zones:
                if zone.is_in_zone(person_location):
                    in_zone_id = zone.zone_id
                    break
            person_trip_map[personId]["DZone"] = in_zone_id

            # Nếu người này chỉ đi bộ nhưng vẫn có computationalRoutingMode là pt/car thì bỏ qua
            # if len(person_trip_map[personId]["vehIdList"]) == 0 or len(person_trip_map[personId]["vehicleTypeList"]) == 0:
            #     del person_trip_map[personId]
        
            # else:
            #     with open(OUTPUT_EVENT_AFTER_PROCESSOR, 'a', newline='') as f:
            #         writer = csv.writer(f)
                    
            #         # Chuẩn bị dữ liệu
            #         # Biến list thành chuỗi, ví dụ dùng dấu ';' để phân cách các ID bên trong
            #         veh_ids = ";".join(map(str, person_trip_map[personId]['vehIdList']))
            #         veh_types = ";".join(map(str, person_trip_map[personId]['vehicleTypeList']))

            #         schema = ['vehIdList', 'vehicleTypeList', 'mainMode' , 'travelTime', 'OZone', 'DZone', 'actstart', 'actend', 'startTime']
                    
            #         row = [
            #             veh_ids,
            #             veh_types,
            #             person_trip_map[personId]['mainMode'],
            #             person_trip_map[personId]['travelTime'],
            #             person_trip_map[personId]['OZone'],
            #             person_trip_map[personId]['DZone'],
            #             person_trip_map[personId]['actstart'],
            #             person_trip_map[personId]['actend'],
            #             person_trip_map[personId]['startTime']
                        
            #         ]
                    
            #         # Ghi cả dòng một lần duy nhất
            #         writer.writerow(row)
            #     del person_trip_map[personId]
            with open(OUTPUT_EVENT_AFTER_PROCESSOR, 'a', newline='') as f:
                writer = csv.writer(f)
                
                # Chuẩn bị dữ liệu
                # Biến list thành chuỗi, ví dụ dùng dấu ';' để phân cách các ID bên trong
                veh_ids = ";".join(map(str, person_trip_map[personId]['vehIdList']))
                veh_types = ";".join(map(str, person_trip_map[personId]['vehicleTypeList']))

                schema = ['vehIdList', 'vehicleTypeList', 'mainMode' , 'travelTime', 'OZone', 'DZone', 'actstart', 'actend', 'xO', 'yO', 'xD', 'yD', 'startTime']
                
                row = [
                    veh_ids,
                    veh_types,
                    person_trip_map[personId]['mainMode'],
                    person_trip_map[personId]['travelTime'],
                    person_trip_map[personId]['OZone'],
                    person_trip_map[personId]['DZone'],
                    person_trip_map[personId]['actstart'],
                    person_trip_map[personId]['actend'],
                    person_trip_map[personId]['xO'],
                    person_trip_map[personId]['yO'],
                    xD,
                    yD,
                    person_trip_map[personId]['startTime']
                    
                ]
                
                # Ghi cả dòng một lần duy nhất
                writer.writerow(row)
            del person_trip_map[personId]

    elem.clear()

print("Finished processing travel data.")
# Out:
# Network bounds: X(439460.06825334975, 483552.56240213366), Y(5711222.598506039, 5766338.24313264)
# Finished processing travel data.

# %% [markdown]
# # Vẽ đồ thị

# %%
# --- BƯỚC 1: XỬ LÝ DỮ LIỆU & TẠO FILE DEBUG ---
df = pd.read_csv(OUTPUT_EVENT_AFTER_PROCESSOR)
df.columns = df.columns.str.strip()

# Chuẩn hóa chuỗi (xóa khoảng trắng, xử lý giá trị rỗng)
for col in ['vehIdList', 'vehicleTypeList', 'mainMode', 'OZone', 'DZone']:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip().replace(['nan', 'None', 'undefined', ''], '')

def get_drawmode(row):
    vid, vtype = row['vehIdList'], row['vehicleTypeList']
    mmode = row['mainMode'].lower()
    
    if not vid and not vtype: return 'walk'
    if mmode == 'car': return 'car'
    if mmode == 'pt':
        return 'bus' if 'bus' in vtype.lower() else 'pt not bus'
    return mmode if mmode else 'unknown'

df['drawmode'] = df.apply(get_drawmode, axis=1)
df['travelTime'] = pd.to_numeric(df['travelTime'], errors='coerce')
# --- NEW: Convert startTime to numeric for Item C processing ---
df['startTime'] = pd.to_numeric(df['startTime'], errors='coerce')

# Lưu file debug
df.to_csv(OUTPUT_EVENT_AFTER_PROCESSOR_IN_DRAW_MODE, index=False)

# --- BƯỚC 2: HÀM VẼ BÁO CÁO TỔNG HỢP ---
def generate_final_report(data_df, folder_name):
    if os.path.exists(folder_name): shutil.rmtree(folder_name)
    os.makedirs(folder_name)
    
    def create_combined_fig(subset_in, title, filename):
        subset = subset_in.copy() # Avoid SettingWithCopyWarning
        
        # --- C. PREPARE DATA FOR TIME ANALYSIS ---
        if 'startTime' in subset.columns:
            subset['start_hour'] = subset['startTime'] / 3600
        else:
             subset['start_hour'] = 0 # Fallback

        # UPDATE: Change layout to 3x2 to include Time analysis (Item C)
        fig, axes = plt.subplots(3, 2, figsize=(18, 20)) 
        fig.suptitle(f"{title}\n(Tổng cộng: {len(subset)} Trip)", fontsize=22, fontweight='bold', y=0.98)
        
        # 1. Tỷ lệ phương tiện
        mode_counts = subset['drawmode'].value_counts()
        axes[0, 0].pie(mode_counts, labels=mode_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
        axes[0, 0].set_title("Tỷ lệ phương tiện", fontsize=16)
        
        # 2. Thời gian trung bình (Modified for Item A & B.1)
        avg_times = subset.groupby('drawmode')['travelTime'].mean().sort_values(ascending=False)
        
        # Fix Item A: Added hue and legend=False to silence warning
        sns.barplot(x=avg_times.index, y=avg_times.values, ax=axes[0, 1], palette='viridis', hue=avg_times.index, legend=False)
        
        for i, mode in enumerate(avg_times.index):
            v = avg_times[mode]
            count = mode_counts.get(mode, 0) 
            # Item B.1: Add n=... to text
            axes[0, 1].text(i, v, f'{v:.1f}\n(n={count})', ha='center', va='bottom', fontweight='bold')
        axes[0, 1].set_title("Thời gian di chuyển trung bình (giây)", fontsize=16)
        
        # 3 & 4. Boxplots Bus và Car tách biệt
        for idx, mode_name, color in [( (1,0), 'bus', 'skyblue'), ((1,1), 'car', 'salmon')]:
            m_data = subset[subset['drawmode'] == mode_name]['travelTime']
            ax = axes[idx]
            if not m_data.empty:
                sns.boxplot(y=m_data, ax=ax, color=color, showfliers=False)
                q1, med, q3 = np.percentile(m_data, [25, 50, 75])
                ax.text(0, med, f'Med: {med:.1f}', ha='center', fontweight='bold', bbox=dict(facecolor='white', alpha=0.5))
                ax.text(0.1, q1, f'25%: {q1:.1f}', color='blue', fontweight='bold')
                ax.text(0.1, q3, f'75%: {q3:.1f}', color='red', fontweight='bold')
                ax.set_title(f"Phân vị: {mode_name.upper()} (N={len(m_data)})", fontsize=16)
            else:
                ax.text(0.5, 0.5, f"Không có dữ liệu {mode_name.upper()}", ha='center')

        # --- C. ITEM SUGGESTION: DEPARTURE TIME PLOTS ---
        # 5. Departure Time Distribution (Histogram)
        ax_hist = axes[2, 0]
        sns.histplot(data=subset, x='start_hour', hue='drawmode', kde=True, ax=ax_hist, element="step", common_norm=False)
        ax_hist.set_title("Phân bố giờ khởi hành (Departure Time)", fontsize=16)
        ax_hist.set_xlabel("Hour of Day")
        ax_hist.set_ylabel("Count")
        
        # 6. Average Travel Time by Hour (Line Plot)
        ax_line = axes[2, 1]
        subset['hour_int'] = subset['start_hour'].astype(int)
        # Group by hour and mode
        time_trend = subset.groupby(['hour_int', 'drawmode'])['travelTime'].mean().reset_index()
        if not time_trend.empty:
            sns.lineplot(data=time_trend, x='hour_int', y='travelTime', hue='drawmode', ax=ax_line, marker='o')
        ax_line.set_title("Biến động thời gian di chuyển theo giờ", fontsize=16)
        ax_line.set_xlabel("Hour of Day")
        ax_line.set_ylabel("Avg Travel Time (s)")
        ax_line.grid(True, linestyle='--', alpha=0.7)

        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.savefig(os.path.join(folder_name, filename))
        plt.close()

    # Tạo ảnh Tổng thể và Top 3 OD
    create_combined_fig(df, f"BÁO CÁO TỔNG QUAN HỆ THỐNG {NAME_SCENARIO}", "00_global_summary.png")
    od_counts = df.groupby(['OZone', 'DZone']).size().reset_index(name='n').sort_values('n', ascending=False)
    for i, (_, row) in enumerate(od_counts.head(10).iterrows(), 1):
        o, d = row['OZone'], row['DZone']
        create_combined_fig(df[(df['OZone']==o) & (df['DZone']==d)], f"TOP {i} OD: {o} -> {d} {NAME_SCENARIO}", f"top_{i}_OD_{o}_{d}_{NAME_SCENARIO}.png")

generate_final_report(OUTPUT_EVENT_AFTER_PROCESSOR, OUTPUT_RESULT_FOLDER)

# %%
import matplotlib.patches as patches
from matplotlib.collections import LineCollection
from matplotlib.path import Path

def draw_top_5_od_map_v11(network_path, schedule_path, zones_list, data_df, output_folder, grid_info="20x20"):
    print("Generating V11 Top 5 OD Map (Refined Colors & Transparency)...")
    
    # 1. Parse Network
    tree = etree.parse(network_path)
    root = tree.getroot()
    nodes = {}
    for node in root.xpath('//network/nodes/node'):
        nodes[node.get('id')] = (float(node.get('x')), float(node.get('y')))
    links = {}
    for link in root.xpath('//network/links/link'):
        links[link.get('id')] = (link.get('from'), link.get('to'))

    # 2. Parse Bus Links
    bus_link_ids = set()
    if os.path.exists(schedule_path):
        try:
            tree_sched = etree.parse(schedule_path)
            root_sched = tree_sched.getroot()
            for route in root_sched.xpath('//transitRoute'):
                mode = route.find('transportMode')
                if mode is not None and mode.text.strip().lower() == 'bus':
                     r_path = route.find('route')
                     if r_path is not None:
                         for link_ref in r_path.xpath('link'):
                             bus_link_ids.add(link_ref.get('refId'))
        except Exception as e:
            print(f"Error parsing schedule: {e}")
    print(f"Found {len(bus_link_ids)} unique bus links.")

    # 3. Data Prep
    valid_df = data_df.copy()
    for col in ['xO', 'yO', 'xD', 'yD']:
        if col in valid_df.columns:
            valid_df[col] = pd.to_numeric(valid_df[col], errors='coerce')
    plot_df = valid_df.dropna(subset=['xO', 'yO', 'xD', 'yD'])
    ranking_df = valid_df[(valid_df['OZone'] != 'undefined') & (valid_df['DZone'] != 'undefined')]
    top_od_counts = ranking_df.groupby(['OZone', 'DZone']).size().reset_index(name='count').sort_values('count', ascending=False).head(5)

    if top_od_counts.empty:
        print("No valid OD pairs found.")
        return

    # 4. Setup Plot
    fig, ax = plt.subplots(figsize=(24, 24), facecolor='black')
    ax.set_facecolor('black')
    ax.set_aspect('equal')

    # Z-Orders
    Z_BASE = 1
    Z_POINTS = 2
    Z_BUS = 3
    Z_ZONES = 4
    Z_ARROWS = 5

    # Layer 1: Background Network
    base_lines = []
    for l_id, (u, v) in links.items():
        if u in nodes and v in nodes:
            base_lines.append([nodes[u], nodes[v]])
    lc_base = LineCollection(base_lines, colors='#cccccc', linewidths=0.5, alpha=0.3, zorder=Z_BASE)
    ax.add_collection(lc_base)

    # Layer 2: Trip Points (Refined Colors)
    # Origin: Light Blue (#ADD8E6)
    # Destination: Medium Pink (#FF69B4)
    ax.scatter(plot_df['xO'], plot_df['yO'], c='#4ec6ed', s=10, alpha=0.6, label='Origins', edgecolors='none', zorder=Z_POINTS)
    ax.scatter(plot_df['xD'], plot_df['yD'], c='#f03793', s=10, alpha=0.6, label='Destinations', edgecolors='none', zorder=Z_POINTS)

    # Layer 3: Bus Network (Red)
    bus_lines = []
    for l_id in bus_link_ids:
        if l_id in links:
            u, v = links[l_id]
            if u in nodes and v in nodes:
                bus_lines.append([nodes[u], nodes[v]])
    if bus_lines:
        lc_bus = LineCollection(bus_lines, colors='#f2f218', linewidths=2.5, alpha=1, zorder=Z_BUS)
        ax.add_collection(lc_bus)

    # Bounds
    rank_colors = ['#FF3333', '#FF9933', '#FFFF33', '#33FF33', '#33FFFF']
    zone_map = {z.zone_id: z for z in zones_list}
    unique_zones = set(top_od_counts['OZone']).union(set(top_od_counts['DZone']))
    
    min_x, max_x = float('inf'), float('-inf')
    min_y, max_y = float('inf'), float('-inf')
    for z_id in unique_zones:
        zone = zone_map.get(z_id)
        if zone:
            xs = [p.x for p in zone.boundary]
            ys = [p.y for p in zone.boundary]
            min_x, max_x = min(min_x, min(xs)), max(max_x, max(xs))
            min_y, max_y = min(min_y, min(ys)), max(max_y, max(ys))

    # Layer 4: Zones (Increased Transparency)
    # Previous ~0.9 or default. Now 0.3 (Double transparency relative to opaque-ish)
    for z_id in unique_zones:
        zone = zone_map.get(z_id)
        if not zone: continue
        # facecolor was #222222, now adding alpha=0.3
        poly = patches.Polygon([(p.x, p.y) for p in zone.boundary], closed=True, 
                               facecolor='#222222', edgecolor='white', alpha=0.6, linewidth=2.0, zorder=Z_ZONES)
        ax.add_patch(poly)
        xs = [p.x for p in zone.boundary]
        ys = [p.y for p in zone.boundary]
        ax.text(min(xs)+50, max(ys)-50, z_id, color='white', fontsize=11, fontweight='bold', ha='left', va='top', zorder=Z_ZONES+0.1)

    # Layer 5: Arrows
    cell_text = []
    table_colors = []
    
    for idx, (i, row) in enumerate(top_od_counts.iterrows()):
        color = rank_colors[idx % 5]
        o_id, d_id = row['OZone'], row['DZone']
        
        o_z, d_z = zone_map.get(o_id), zone_map.get(d_id)
        if not o_z or not d_z: continue
        
        ox = sum(p.x for p in o_z.boundary)/len(o_z.boundary)
        oy = sum(p.y for p in o_z.boundary)/len(o_z.boundary)
        dx = sum(p.x for p in d_z.boundary)/len(d_z.boundary)
        dy = sum(p.y for p in d_z.boundary)/len(d_z.boundary)
        
        if o_id == d_id:
            z_xs = [p.x for p in o_z.boundary]
            z_width = max(z_xs) - min(z_xs)
            r = z_width * 0.25 
            theta = np.linspace(np.radians(30), np.radians(330), 50)
            arc_xs = ox + r * np.cos(theta)
            arc_ys = oy + r * np.sin(theta)
            verts = list(zip(arc_xs, arc_ys))
            p = Path(verts)
            arrow = patches.FancyArrowPatch(path=p, arrowstyle='-|>', color=color, lw=3, mutation_scale=20, zorder=Z_ARROWS)
            ax.add_patch(arrow)
        else:
            rad = 0.2 + (0.05 * idx)
            arrow = patches.FancyArrowPatch((ox, oy), (dx, dy), connectionstyle=f"arc3,rad={rad}", 
                                            arrowstyle='-|>', color=color, lw=3, mutation_scale=25, zorder=Z_ARROWS)
            ax.add_patch(arrow)
        
        cell_text.append([o_id, d_id, str(row['count'])])
        table_colors.append([color, color, '#333333'])

    if min_x != float('inf'):
        pad_x = (max_x - min_x) * 0.2
        pad_y = (max_y - min_y) * 0.2
        ax.set_xlim(min_x - pad_x, max_x + pad_x)
        ax.set_ylim(min_y - pad_y, max_y + pad_y)
        
    ax.set_title(f"TOP 5 OD FLOW: {NAME_SCENARIO}", fontsize=24, color='white', pad=20)
    ax.text(0.02, 0.98, f"Grid: {grid_info}\nYellow: Bus Routes\nPoints: O=Light Blue, D=Medium Pink", transform=ax.transAxes, 
            color='white', fontsize=12, fontweight='bold', va='top', 
            bbox=dict(facecolor='black', alpha=0.5, edgecolor='none'))
    ax.axis('off')

    if cell_text:
        the_table = ax.table(cellText=cell_text,
                             colLabels=["Origin", "Destination", "Trips"],
                             cellColours=table_colors,
                             cellLoc='center',
                             loc='upper right',
                             bbox=[0.72, 0.85, 0.26, 0.13]) 
        the_table.auto_set_font_size(False)
        the_table.set_fontsize(9)
        for (r, c), cell in the_table.get_celld().items():
             cell.set_edgecolor('white')
             cell.set_linewidth(0.5)
             if r == 0:
                 cell.set_facecolor('#dddddd')
                 cell.set_text_props(weight='bold', color='black')
             else:
                 if c < 2:
                     cell.set_text_props(weight='bold', color='black')
                 else:
                     cell.set_text_props(color='white')

    save_path = os.path.join(output_folder, f"Top5_OD_Vis_Final_v11_{NAME_SCENARIO}.png")
    plt.savefig(save_path, dpi=150, bbox_inches='tight', facecolor='black')
    plt.close()
    print(f"Map saved to: {save_path}")

draw_top_5_od_map_v11(NETWORK_PATH, SCHEDULE_PATH, simple_zones, df, OUTPUT_RESULT_FOLDER, grid_info="20x20")
# Out:
# Generating V11 Top 5 OD Map (Refined Colors & Transparency)...
# Found 912 unique bus links.
# Map saved to: data\before\scoring\estimate_impact_to_OD\visaulize\Top5_OD_Vis_Final_v11_BEFORE IMPROVEMENT.png
